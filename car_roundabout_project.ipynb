# %% [markdown]
# ##  Reinforcement Learning project notebook

# %% [markdown]
# #### We will import all the libraries that are needed for the project.

# %%
# Import Dependencies
#!pip install stable_baselines    
#!pip install matplotlib

# %%
from stable_baselines import HER, SAC, PPO2, DQN
import highway_env
import numpy as np
import gym
import matplotlib.pyplot as plt
import pprint
from statistics import mean
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %% [markdown]
# ## Roundabout setup

# %%
# Setting up the environment for roundabout
env = gym.make('roundabout-v0')

# %% [markdown]
# #### Using the env.config to look at the configurations available and the default values for this configuration.

# %%
pprint.pprint(env.config)
# Out:
# {'action': {'target_speeds': [0, 8, 16], 'type': 'DiscreteMetaAction'},
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -1,
#  'duration': 11,
#  'high_speed_reward': 0.2,
#  'incoming_vehicle_destination': None,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'observation': {'absolute': True,
#                  'features_range': {'vx': [-15, 15],
#                                     'vy': [-15, 15],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'right_lane_reward': 0,
#  'scaling': 5.5,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# #### I am going to change some of the default values of the rewards. I believe that with the default values in the configuration led to rewards that were too good to be true

# %% [markdown]
# #### By changing the default values I add some noise  and more difficulty and test the agent. I have assigned a very high negative reward when the car collides and a good enough reward if the car drives on high speed as compared to the default values in config

# %%
env.config["collision_reward"] = -8
env.config['high_speed_reward'] = 1
env.reset()
# Out:
# array([[ 1.0000000e+00,  2.0000000e-02,  4.4999999e-01,  0.0000000e+00,
#         -5.3333336e-01],
#        [ 1.0000000e+00, -1.7955920e-02,  1.9919233e-01,  1.0000000e+00,
#          9.9252149e-02],
#        [ 1.0000000e+00, -1.8256707e-01,  1.5578596e-01,  6.7975676e-01,
#          7.9661351e-01],
#        [ 1.0000000e+00,  1.0000000e+00, -2.0000000e-02, -1.0000000e+00,
#          2.2204460e-16],
#        [ 1.0000000e+00, -1.6724715e-01, -1.0967404e-01, -4.9941036e-01,
#          7.6157457e-01]], dtype=float32)

# %% [markdown]
# ## GREEDY WITH ROUNDABOUT

# %% [markdown]
# ### Performance of agents taking random actions
#
# Reward function: We will look at the reward function to evaluate the performance of the agent taking greedy actions. I take the reward from each loop and then find the average of all the rewards.
#
# Number of crashes: The second method to evaluate the performance of the agent taking the greedy function is to count the number of crashes.

# %%
# Writing a function for calculating the average of the rewards.

def Average(l): 
    avg = mean(l) 
    return avg


crashcount = 0
for i in range(100):
    done = False
    env.reset()
    total_reward = []
    while not done:
        env.render()
        #render the next actions, rewards and states.
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        if info['crashed']==True : crashcount +=1
        total_reward.append(reward)
        print(info)
        print(done)
        
        
rewards_average = Average(total_reward) 
  
print("The average of rewards: ",rewards_average)
print("Number of Crashes: ", crashcount)
env.close()
# Out:
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 0}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 10.263391338495092, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 3}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 6.632894292898015, 'crashed': False, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 9.133483567140011, 'crashed': False, 'action': 4}
# False
# {'speed': 8.193699005766298, 'crashed': False, 'action': 0}
# False
# {'speed': 14.66599500413512, 'crashed': False, 'action': 3}
# False
# {'speed': 15.772034241274199, 'crashed': False, 'action': 1}
# False
# {'speed': 15.96104333393614, 'crashed': False, 'action': 2}
# False
# {'speed': 9.360448641118547, 'crashed': False, 'action': 4}
# False
# {'speed': 8.23248466658028, 'crashed': False, 'action': 2}
# False
# {'speed': 1.406834771258672, 'crashed': False, 'action': 4}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 8.236634980349653, 'crashed': True, 'action': 3}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 6.281310678251284, 'crashed': True, 'action': 4}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 11.033761700650496, 'crashed': True, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 3}
# False
# {'speed': 15.999965953291689, 'crashed': False, 'action': 2}
# False
# {'speed': 15.999994181818122, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 0}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 2}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 3}
# False
# {'speed': 9.367071830300809, 'crashed': False, 'action': 4}
# False
# {'speed': 1.6007223686963536, 'crashed': False, 'action': 4}
# False
# {'speed': 0.27354461971309335, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 6.63309335676719, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1335176138483234, 'crashed': False, 'action': 4}
# False
# {'speed': 0.1937048239481749, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0331018754030709, 'crashed': False, 'action': 2}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 8.868111869562963, 'crashed': True, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 2}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 2}
# False
# {'speed': 9.366906643232811, 'crashed': False, 'action': 4}
# False
# {'speed': 14.866482386151677, 'crashed': False, 'action': 3}
# False
# {'speed': 15.806295176051826, 'crashed': False, 'action': 0}
# False
# {'speed': 15.96689812459693, 'crashed': False, 'action': 0}
# False
# {'speed': 15.994343278949556, 'crashed': False, 'action': 2}
# False
# {'speed': 15.999033332925917, 'crashed': False, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 12.43054354837522, 'crashed': True, 'action': 3}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 11.033761700650496, 'crashed': True, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 6.63309335676719, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766411736839202, 'crashed': False, 'action': 2}
# False
# {'speed': 7.9600825140790645, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 0}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 2}
# False
# {'speed': 7.994343448856691, 'crashed': False, 'action': 1}
# False
# {'speed': 7.999033361961048, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632728935922879, 'crashed': False, 'action': 3}
# False
# {'speed': 9.133455338613578, 'crashed': False, 'action': 4}
# False
# {'speed': 8.220261646785515, 'crashed': True, 'action': 3}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 11.857383708634414, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 9.327182572906308, 'crashed': False, 'action': 4}
# False
# {'speed': 8.226799886910536, 'crashed': False, 'action': 2}
# False
# {'speed': 8.038757432287548, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3737290661913826, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23475413497606143, 'crashed': False, 'action': 1}
# False
# {'speed': 0.04011671969724577, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006855475408054032, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 2}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 1}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 0}
# False
# {'speed': 9.366906643232811, 'crashed': False, 'action': 4}
# False
# {'speed': 1.6006941401699197, 'crashed': False, 'action': 4}
# False
# {'speed': 0.2735397957900449, 'crashed': False, 'action': 0}
# False
# {'speed': 6.679638855793434, 'crashed': False, 'action': 3}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 8.236634980349653, 'crashed': True, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 6.639716545949451, 'crashed': False, 'action': 3}
# False
# {'speed': 14.40043768493703, 'crashed': False, 'action': 3}
# False
# {'speed': 15.726653619804388, 'crashed': False, 'action': 2}
# False
# {'speed': 15.953288319646925, 'crashed': False, 'action': 0}
# False
# {'speed': 15.992017523408043, 'crashed': False, 'action': 0}
# False
# {'speed': 15.998635888667256, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999766889422515, 'crashed': False, 'action': 1}
# False
# {'speed': 9.367066041154063, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1403059900985835, 'crashed': False, 'action': 4}
# False
# {'speed': 6.8277590005724385, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1667836820605637, 'crashed': False, 'action': 4}
# False
# {'speed': 0.19938960361791735, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03407333736507175, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0058227324701380125, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0009950364725221897, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 6.639716545949451, 'crashed': False, 'action': 3}
# False
# {'speed': 14.40043768493703, 'crashed': False, 'action': 3}
# False
# {'speed': 15.726653619804388, 'crashed': False, 'action': 0}
# False
# {'speed': 15.953288319646925, 'crashed': False, 'action': 1}
# False
# {'speed': 15.992017523408043, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998635888667256, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999766889422515, 'crashed': False, 'action': 3}
# False
# {'speed': 15.999960164144941, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 13.497872162473755, 'crashed': True, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 4.012894602048116, 'crashed': True, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 9.133483567140011, 'crashed': False, 'action': 4}
# False
# {'speed': 3.843532660411516, 'crashed': True, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 9.360283454050553, 'crashed': False, 'action': 4}
# False
# {'speed': 8.23245643805385, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 6.634059994806141, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766576923907201, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3272166196146198, 'crashed': False, 'action': 4}
# False
# {'speed': 6.859699828083294, 'crashed': False, 'action': 3}
# False
# {'speed': 14.438030239668148, 'crashed': False, 'action': 3}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 2}
# False
# {'speed': 6.632899941172757, 'crashed': False, 'action': 3}
# False
# {'speed': 7.76637868438972, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3271827428134442, 'crashed': False, 'action': 4}
# False
# {'speed': 6.859694038936547, 'crashed': False, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 13.680209181147085, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 12.43054354837522, 'crashed': True, 'action': 3}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 2}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 2}
# False
# {'speed': 14.62723757184757, 'crashed': False, 'action': 3}
# False
# {'speed': 9.132516929101062, 'crashed': False, 'action': 4}
# False
# {'speed': 8.1935338186983, 'crashed': False, 'action': 0}
# False
# {'speed': 8.033072652617808, 'crashed': False, 'action': 2}
# False
# {'speed': 8.00565172722026, 'crashed': False, 'action': 2}
# False
# {'speed': 1.36807169069638, 'crashed': False, 'action': 4}
# False
# {'speed': 0.2337873560651032, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 0}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 0}
# False
# {'speed': 14.62723757184757, 'crashed': False, 'action': 3}
# False
# {'speed': 12.73702656177052, 'crashed': True, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 0}
# False
# {'speed': 12.092826060762134, 'crashed': True, 'action': 3}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 2}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3614493258658122, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23265567183015726, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03975811703481418, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006794194432138867, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011610478922149622, 'crashed': False, 'action': 0}
# False
# {'speed': 0.000198409424617016, 'crashed': False, 'action': 2}
# False
# {'speed': 3.390583630599011e-05, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1403059900985835, 'crashed': False, 'action': 4}
# False
# {'speed': 6.8277590005724385, 'crashed': False, 'action': 3}
# False
# {'speed': 7.7996778050514415, 'crashed': False, 'action': 0}
# False
# {'speed': 7.965767293748808, 'crashed': False, 'action': 0}
# False
# {'speed': 7.994150033262259, 'crashed': False, 'action': 2}
# False
# {'speed': 7.999000309511565, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 6.6329281696991895, 'crashed': False, 'action': 3}
# False
# {'speed': 14.399277631303644, 'crashed': False, 'action': 3}
# False
# {'speed': 15.726455380286904, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 6.6329281696991895, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766383508312769, 'crashed': False, 'action': 0}
# False
# {'speed': 7.960077690156016, 'crashed': False, 'action': 2}
# False
# {'speed': 7.9931777469485645, 'crashed': False, 'action': 0}
# False
# {'speed': 7.998834157219868, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 7.773200113089462, 'crashed': False, 'action': 1}
# False
# {'speed': 7.96124256771245, 'crashed': False, 'action': 0}
# False
# {'speed': 7.993376810817739, 'crashed': False, 'action': 2}
# False
# {'speed': 7.998868174893048, 'crashed': False, 'action': 1}
# False
# {'speed': 7.999806584405567, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3670728245596395, 'crashed': False, 'action': 4}
# False
# {'speed': 0.2336166615943679, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992233887911393, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 2}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 1}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3614493258658122, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23265567183015726, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03975811703481418, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006794194432138867, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 1}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 1}
# False
# {'speed': 7.994343448856691, 'crashed': False, 'action': 1}
# False
# {'speed': 7.999033361961048, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3669406899411227, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23359408134267662, 'crashed': False, 'action': 1}
# False
# {'speed': 6.672812603170644, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1403051657468901, 'crashed': False, 'action': 4}
# False
# {'speed': 0.19486473670955423, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 9.360283454050553, 'crashed': False, 'action': 4}
# False
# {'speed': 8.23245643805385, 'crashed': False, 'action': 0}
# False
# {'speed': 1.4068299473356247, 'crashed': False, 'action': 4}
# False
# {'speed': 0.24041068611937064, 'crashed': False, 'action': 4}
# False
# {'speed': 0.041083357736198346, 'crashed': False, 'action': 2}
# False
# {'speed': 0.007020662476053114, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011997486164387026, 'crashed': False, 'action': 2}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 0}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 3}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 1}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 3}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999965953291689, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999994181818122, 'crashed': False, 'action': 0}
# False
# {'speed': 15.99999900574117, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999999830092865, 'crashed': False, 'action': 2}
# False
# {'speed': 15.99999997096487, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 3}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999965953291689, 'crashed': False, 'action': 2}
# False
# {'speed': 15.999994181818122, 'crashed': False, 'action': 3}
# False
# {'speed': 15.99999900574117, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 6.632894292898015, 'crashed': False, 'action': 3}
# False
# {'speed': 7.76637771916602, 'crashed': False, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 8.236634980349653, 'crashed': True, 'action': 0}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 7.773200113089462, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3283484447215714, 'crashed': False, 'action': 4}
# False
# {'speed': 0.22699912068684838, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03879147899586166, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0066290073641397974, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011328193657815329, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019358550156870988, 'crashed': False, 'action': 2}
# False
# {'speed': 3.308148461229272e-05, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 3}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 9.365940005193858, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1403059900985835, 'crashed': False, 'action': 4}
# False
# {'speed': 0.19486487758155982, 'crashed': False, 'action': 1}
# False
# {'speed': 6.66619423791143, 'crashed': False, 'action': 3}
# False
# {'speed': 14.40496241097339, 'crashed': False, 'action': 3}
# False
# {'speed': 15.727426842248907, 'crashed': False, 'action': 1}
# False
# {'speed': 15.953420454265443, 'crashed': False, 'action': 0}
# False
# {'speed': 9.359145980668854, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 6.634059994806141, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766576923907201, 'crashed': False, 'action': 1}
# False
# {'speed': 7.960110742605498, 'crashed': False, 'action': 1}
# False
# {'speed': 7.993183395223306, 'crashed': False, 'action': 0}
# False
# {'speed': 7.998835122443567, 'crashed': False, 'action': 2}
# False
# {'speed': 7.999800936130825, 'crashed': False, 'action': 1}
# False
# {'speed': 7.9999659823268185, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 6.6329281696991895, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766383508312769, 'crashed': False, 'action': 2}
# False
# {'speed': 7.960077690156016, 'crashed': False, 'action': 2}
# False
# {'speed': 7.9931777469485645, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 14.40609423608034, 'crashed': False, 'action': 3}
# False
# {'speed': 15.727620257843341, 'crashed': False, 'action': 0}
# False
# {'speed': 8.853254019576916, 'crashed': True, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 3.7453682952449086, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 6.63309335676719, 'crashed': False, 'action': 3}
# False
# {'speed': 14.39930585983008, 'crashed': False, 'action': 3}
# False
# {'speed': 15.726460204209955, 'crashed': False, 'action': 0}
# False
# {'speed': 15.953255267197445, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 2}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998834128184738, 'crashed': True, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 8.868111869562963, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1734068712428247, 'crashed': False, 'action': 4}
# False
# {'speed': 0.20052142872486894, 'crashed': False, 'action': 2}
# False
# {'speed': 0.034266752959504244, 'crashed': False, 'action': 1}
# False
# {'speed': 0.005855784919619744, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0010006847472641923, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 2}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 6.632895117249708, 'crashed': False, 'action': 3}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 9.327182572906308, 'crashed': False, 'action': 4}
# False
# {'speed': 8.226799886910536, 'crashed': False, 'action': 0}
# False
# {'speed': 14.671651555278427, 'crashed': False, 'action': 3}
# False
# {'speed': 15.773000879313152, 'crashed': False, 'action': 3}
# False
# {'speed': 15.961208521004139, 'crashed': False, 'action': 0}
# False
# {'speed': 15.99337099263586, 'crashed': False, 'action': 2}
# False
# {'speed': 15.99886718063422, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999806414498432, 'crashed': False, 'action': 2}
# False
# {'speed': 15.99996691851539, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 14.40609423608034, 'crashed': False, 'action': 3}
# False
# {'speed': 15.727620257843341, 'crashed': False, 'action': 2}
# False
# {'speed': 15.953453506714926, 'crashed': False, 'action': 1}
# False
# {'speed': 15.992045751934477, 'crashed': False, 'action': 0}
# False
# {'speed': 15.998640712590303, 'crashed': False, 'action': 3}
# False
# {'speed': 15.99976771377421, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999960305016947, 'crashed': False, 'action': 2}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 6.530610075898225, 'crashed': True, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 0}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 2}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 3}
# False
# {'speed': 15.999965953291689, 'crashed': False, 'action': 0}
# False
# {'speed': 9.367100058827244, 'crashed': False, 'action': 4}
# False
# {'speed': 14.866515438601159, 'crashed': False, 'action': 3}
# False
# {'speed': 15.806300824326566, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 6.634059994806141, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766576923907201, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3272166196146198, 'crashed': False, 'action': 4}
# False
# {'speed': 0.22680570509241577, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03875842654637992, 'crashed': False, 'action': 1}
# False
# {'speed': 6.639517482080276, 'crashed': False, 'action': 3}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 5.938550721701828, 'crashed': True, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 1}
# False
# {'speed': 14.599793241846637, 'crashed': False, 'action': 3}
# False
# {'speed': 15.760721138987579, 'crashed': False, 'action': 2}
# False
# {'speed': 15.959110057858235, 'crashed': False, 'action': 3}
# False
# {'speed': 15.99301238997343, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998805899658304, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999795942300644, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999965128939992, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999994040946115, 'crashed': False, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 2}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 3}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999965953291689, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999994181818122, 'crashed': False, 'action': 3}
# False
# {'speed': 15.99999900574117, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999999830092865, 'crashed': False, 'action': 1}
# False
# {'speed': 15.99999997096487, 'crashed': False, 'action': 0}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 6.530610075898225, 'crashed': True, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 2}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 0}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 3}
# False
# {'speed': 9.366906643232811, 'crashed': False, 'action': 4}
# False
# {'speed': 8.233588263160799, 'crashed': False, 'action': 1}
# False
# {'speed': 8.039917485920935, 'crashed': False, 'action': 1}
# False
# {'speed': 8.006821428699745, 'crashed': False, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 2}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 3}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999965953291689, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999994181818122, 'crashed': False, 'action': 0}
# False
# {'speed': 15.99999900574117, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999999830092865, 'crashed': False, 'action': 3}
# False
# {'speed': 15.99999997096487, 'crashed': False, 'action': 3}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1403059900985835, 'crashed': False, 'action': 4}
# False
# {'speed': 0.19486487758155982, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03330011492055168, 'crashed': False, 'action': 1}
# False
# {'speed': 0.005690597851620667, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0009724562208307615, 'crashed': False, 'action': 2}
# False
# {'speed': 6.633060304317707, 'crashed': False, 'action': 3}
# False
# {'speed': 7.76640608856446, 'crashed': False, 'action': 0}
# False
# {'speed': 7.960081548855366, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 6.63309335676719, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766411736839202, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3271883910881865, 'crashed': False, 'action': 4}
# False
# {'speed': 0.22680088116936753, 'crashed': False, 'action': 2}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 3}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 0}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 3}
# False
# {'speed': 9.366906643232811, 'crashed': False, 'action': 4}
# False
# {'speed': 8.233588263160799, 'crashed': False, 'action': 0}
# False
# {'speed': 8.039917485920935, 'crashed': False, 'action': 1}
# False
# {'speed': 8.006821428699745, 'crashed': False, 'action': 1}
# False
# {'speed': 14.634059824899005, 'crashed': False, 'action': 3}
# False
# {'speed': 15.766576894872069, 'crashed': False, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 3}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 3}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 2}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 0}
# False
# {'speed': 9.367071830300809, 'crashed': False, 'action': 4}
# False
# {'speed': 1.6007223686963536, 'crashed': False, 'action': 4}
# False
# {'speed': 0.27354461971309335, 'crashed': False, 'action': 2}
# False
# {'speed': 6.6796396801451285, 'crashed': False, 'action': 3}
# False
# {'speed': 7.774365955869595, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 6.632894292898015, 'crashed': False, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 6.63309335676719, 'crashed': False, 'action': 3}
# False
# {'speed': 7.766411736839202, 'crashed': False, 'action': 0}
# False
# {'speed': 7.9600825140790645, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 12.43054354837522, 'crashed': True, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1734068712428247, 'crashed': False, 'action': 4}
# False
# {'speed': 0.20052142872486894, 'crashed': False, 'action': 0}
# False
# {'speed': 6.667160875950383, 'crashed': False, 'action': 3}
# False
# {'speed': 7.77223347505051, 'crashed': False, 'action': 0}
# False
# {'speed': 7.961077380644451, 'crashed': False, 'action': 2}
# False
# {'speed': 7.993348582291304, 'crashed': False, 'action': 0}
# False
# {'speed': 14.631757473960878, 'crashed': False, 'action': 3}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 9.133483567140011, 'crashed': False, 'action': 4}
# False
# {'speed': 8.193699005766298, 'crashed': False, 'action': 1}
# False
# {'speed': 8.033100881144243, 'crashed': False, 'action': 2}
# False
# {'speed': 8.00565655114331, 'crashed': False, 'action': 0}
# False
# {'speed': 8.000966638038953, 'crashed': False, 'action': 2}
# False
# {'speed': 4.013163674375593, 'crashed': True, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 3}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 0}
# False
# {'speed': 9.360283454050553, 'crashed': False, 'action': 4}
# False
# {'speed': 1.5995623150629688, 'crashed': False, 'action': 4}
# False
# {'speed': 0.2733463801956126, 'crashed': False, 'action': 4}
# False
# {'speed': 0.046711680353073964, 'crashed': False, 'action': 2}
# False
# {'speed': 6.640876599582835, 'crashed': False, 'action': 3}
# False
# {'speed': 7.767741801463635, 'crashed': False, 'action': 2}
# False
# {'speed': 14.593203929465552, 'crashed': False, 'action': 3}
# False
# {'speed': 15.759595103027378, 'crashed': False, 'action': 0}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 7.773200113089462, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3283484447215714, 'crashed': False, 'action': 4}
# False
# {'speed': 0.22699912068684838, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03879147899586166, 'crashed': False, 'action': 1}
# False
# {'speed': 6.639523130355019, 'crashed': False, 'action': 3}
# False
# {'speed': 14.40040463248755, 'crashed': False, 'action': 3}
# False
# {'speed': 15.726647971529646, 'crashed': False, 'action': 3}
# False
# {'speed': 9.320393231432348, 'crashed': False, 'action': 4}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 0}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 0}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 1}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 3}
# False
# {'speed': 15.999800766223688, 'crashed': False, 'action': 0}
# False
# {'speed': 15.999965953291689, 'crashed': False, 'action': 1}
# False
# {'speed': 15.999994181818122, 'crashed': False, 'action': 2}
# False
# {'speed': 15.99999900574117, 'crashed': False, 'action': 3}
# False
# {'speed': 15.999999830092865, 'crashed': False, 'action': 2}
# False
# {'speed': 15.99999997096487, 'crashed': False, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1403059900985835, 'crashed': False, 'action': 4}
# False
# {'speed': 0.19486487758155982, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03330011492055168, 'crashed': False, 'action': 0}
# False
# {'speed': 6.638584720842498, 'crashed': False, 'action': 3}
# False
# {'speed': 7.7673501463517205, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 1}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 1}
# False
# {'speed': 7.994343448856691, 'crashed': False, 'action': 0}
# False
# {'speed': 1.366139238970169, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23345712280111083, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03989507557637984, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006817599035523995, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011650474635695714, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 13.497872162473755, 'crashed': True, 'action': 3}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 1}
# False
# {'speed': 6.632895117249708, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1334837370471478, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 6.866516432859989, 'crashed': False, 'action': 3}
# False
# {'speed': 7.806300994233703, 'crashed': False, 'action': 1}
# False
# {'speed': 7.966899118855758, 'crashed': False, 'action': 0}
# False
# {'speed': 7.994343448856691, 'crashed': False, 'action': 0}
# False
# {'speed': 7.999033361961048, 'crashed': False, 'action': 2}
# False
# {'speed': 7.999834812932002, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3670776484826883, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 9.133483567140011, 'crashed': False, 'action': 4}
# False
# {'speed': 8.193699005766298, 'crashed': False, 'action': 2}
# False
# {'speed': 14.66599500413512, 'crashed': False, 'action': 3}
# False
# {'speed': 15.772034241274199, 'crashed': False, 'action': 0}
# False
# {'speed': 7.962332900067647, 'crashed': True, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 6.6329281696991895, 'crashed': False, 'action': 3}
# False
# {'speed': 14.399277631303644, 'crashed': False, 'action': 3}
# False
# {'speed': 15.726455380286904, 'crashed': False, 'action': 3}
# False
# {'speed': 15.95325444284575, 'crashed': False, 'action': 2}
# False
# {'speed': 9.359117611270417, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 6.634059994806141, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1336828009163222, 'crashed': False, 'action': 4}
# False
# {'speed': 0.19373305247460823, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03310669932611918, 'crashed': False, 'action': 4}
# False
# {'speed': 0.005657545402138929, 'crashed': False, 'action': 2}
# False
# {'speed': 0.000966807946088758, 'crashed': False, 'action': 1}
# True
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 2}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 3}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998834128184738, 'crashed': False, 'action': 1}
# False
# {'speed': 6.859059784926124, 'crashed': True, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 14.632894122990876, 'crashed': False, 'action': 3}
# False
# {'speed': 15.76637769013089, 'crashed': False, 'action': 1}
# False
# {'speed': 15.960076695897188, 'crashed': False, 'action': 1}
# False
# {'speed': 15.993177577041429, 'crashed': False, 'action': 2}
# False
# {'speed': 15.998834128184738, 'crashed': True, 'action': 1}
# True
# The average of rewards:  0.8425414364640884
# Number of Crashes:  32

# %% [markdown]
# The environment always through random environments at the agent. So, the performance metric used that is the reward function keeps changing after the code snippet is completed
#
# After running the code a few times, I aw that the reward is anywhere from 0.50 to 0.96, which is a pretty good reward in good cases.
#
# The number of crashed out of 100, were only about 30-40.

# %% [markdown]
# ### Agent taking greedy action is not always the best idea. We need an intelligent agent who learns and applies for getting maximum rewards.

# %% [markdown]
# ## PPO WITH ROUNDABOUT
#
# More information on the algorithm can be found in the report.

# %% [markdown]
# ### Creating a ppo model
#
#
# I set the timesteps at 10000.

# %%
# creating the ppo policy with the roundabout environment
ppo_roundabout = PPO2('MlpPolicy', env, verbose=1)
# Instead of choosing greedily, next step helps the agent learn to take better decisions inturn action

ppo_roundabout.learn(total_timesteps=10000)
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\ppo2\ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\ppo2\ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\ppo2\ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\ppo2\ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\ppo2\ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# --------------------------------------
# | approxkl           | 0.00015213432 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0637       |
# | fps                | 20            |
# | n_updates          | 1             |
# | policy_entropy     | 1.6092974     |
# | policy_loss        | -0.004361937  |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 11.6282015    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.6744505e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0634       |
# | fps                | 21            |
# | n_updates          | 2             |
# | policy_entropy     | 1.6086382     |
# | policy_loss        | -0.0010022947 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 6.12          |
# | total_timesteps    | 256           |
# | value_loss         | 10.776773     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.61318e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0726       |
# | fps                | 21            |
# | n_updates          | 3             |
# | policy_entropy     | 1.607324      |
# | policy_loss        | -0.0023365985 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 12            |
# | total_timesteps    | 384           |
# | value_loss         | 7.9456263     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000102754195 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0602        |
# | fps                | 21             |
# | n_updates          | 4              |
# | policy_entropy     | 1.6057515      |
# | policy_loss        | 7.4219424e-06  |
# | serial_timesteps   | 512            |
# | time_elapsed       | 18             |
# | total_timesteps    | 512            |
# | value_loss         | 7.8089647      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.7503966e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0204       |
# | fps                | 21            |
# | n_updates          | 5             |
# | policy_entropy     | 1.6042547     |
# | policy_loss        | -0.0020696707 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 23.9          |
# | total_timesteps    | 640           |
# | value_loss         | 7.165886      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.7339425e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0191         |
# | fps                | 21             |
# | n_updates          | 6              |
# | policy_entropy     | 1.6017596      |
# | policy_loss        | -0.00038399373 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 29.9           |
# | total_timesteps    | 768            |
# | value_loss         | 6.418352       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.87067e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0179        |
# | fps                | 21            |
# | n_updates          | 7             |
# | policy_entropy     | 1.6003387     |
# | policy_loss        | -0.0023957756 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 35.8          |
# | total_timesteps    | 896           |
# | value_loss         | 5.613536      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.5133204e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0424        |
# | fps                | 21            |
# | n_updates          | 8             |
# | policy_entropy     | 1.5988921     |
# | policy_loss        | 0.00019999186 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 41.7          |
# | total_timesteps    | 1024          |
# | value_loss         | 4.6516166     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.228573e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.139         |
# | fps                | 21            |
# | n_updates          | 9             |
# | policy_entropy     | 1.5999113     |
# | policy_loss        | -0.0006791644 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 47.8          |
# | total_timesteps    | 1152          |
# | value_loss         | 4.4630237     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011667896 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.135         |
# | fps                | 21            |
# | n_updates          | 10            |
# | policy_entropy     | 1.5966166     |
# | policy_loss        | -0.002563243  |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 53.8          |
# | total_timesteps    | 1280          |
# | value_loss         | 4.125541      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00042618622 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.113         |
# | fps                | 20            |
# | n_updates          | 11            |
# | policy_entropy     | 1.5901613     |
# | policy_loss        | -0.0058364635 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 59.8          |
# | total_timesteps    | 1408          |
# | value_loss         | 3.65749       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019157317 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.241         |
# | fps                | 10            |
# | n_updates          | 12            |
# | policy_entropy     | 1.584565      |
# | policy_loss        | 5.090155e-05  |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 66            |
# | total_timesteps    | 1536          |
# | value_loss         | 3.6033657     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025016474 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.246         |
# | fps                | 18            |
# | n_updates          | 13            |
# | policy_entropy     | 1.581507      |
# | policy_loss        | -0.0060044164 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 77.8          |
# | total_timesteps    | 1664          |
# | value_loss         | 3.3815634     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005827864 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.225        |
# | fps                | 19           |
# | n_updates          | 14           |
# | policy_entropy     | 1.5686908    |
# | policy_loss        | -0.006716151 |
# | serial_timesteps   | 1792         |
# | time_elapsed       | 84.5         |
# | total_timesteps    | 1792         |
# | value_loss         | 2.8723102    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0002478512   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.362          |
# | fps                | 18             |
# | n_updates          | 15             |
# | policy_entropy     | 1.5633817      |
# | policy_loss        | -0.00041537022 |
# | serial_timesteps   | 1920           |
# | time_elapsed       | 91.1           |
# | total_timesteps    | 1920           |
# | value_loss         | 2.5399954      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00015452706 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.308         |
# | fps                | 19            |
# | n_updates          | 16            |
# | policy_entropy     | 1.5561084     |
# | policy_loss        | -0.002277994  |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 97.9          |
# | total_timesteps    | 2048          |
# | value_loss         | 2.5754416     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004643398 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.452        |
# | fps                | 21           |
# | n_updates          | 17           |
# | policy_entropy     | 1.551313     |
# | policy_loss        | -0.00428932  |
# | serial_timesteps   | 2176         |
# | time_elapsed       | 104          |
# | total_timesteps    | 2176         |
# | value_loss         | 1.9903404    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001160406   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.444         |
# | fps                | 20            |
# | n_updates          | 18            |
# | policy_entropy     | 1.5310947     |
# | policy_loss        | -0.0064905467 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 111           |
# | total_timesteps    | 2304          |
# | value_loss         | 1.9769529     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010130897 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.518        |
# | fps                | 21           |
# | n_updates          | 19           |
# | policy_entropy     | 1.5032945    |
# | policy_loss        | -0.005813974 |
# | serial_timesteps   | 2432         |
# | time_elapsed       | 117          |
# | total_timesteps    | 2432         |
# | value_loss         | 1.8729749    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0023491883 |
# | clipfrac           | 0.01171875   |
# | explained_variance | 0.415        |
# | fps                | 20           |
# | n_updates          | 20           |
# | policy_entropy     | 1.4672073    |
# | policy_loss        | -0.013829559 |
# | serial_timesteps   | 2560         |
# | time_elapsed       | 123          |
# | total_timesteps    | 2560         |
# | value_loss         | 2.2647321    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012792526  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.701         |
# | fps                | 20            |
# | n_updates          | 21            |
# | policy_entropy     | 1.4315019     |
# | policy_loss        | -0.0025703448 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 129           |
# | total_timesteps    | 2688          |
# | value_loss         | 1.0463781     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007865506 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.706        |
# | fps                | 20           |
# | n_updates          | 22           |
# | policy_entropy     | 1.4040874    |
# | policy_loss        | -0.005848149 |
# | serial_timesteps   | 2816         |
# | time_elapsed       | 135          |
# | total_timesteps    | 2816         |
# | value_loss         | 1.0572584    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00022746989 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.739         |
# | fps                | 21            |
# | n_updates          | 23            |
# | policy_entropy     | 1.3797833     |
# | policy_loss        | -0.0008537129 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 142           |
# | total_timesteps    | 2944          |
# | value_loss         | 0.89220446    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0026311385 |
# | clipfrac           | 0.02734375   |
# | explained_variance | 0.711        |
# | fps                | 21           |
# | n_updates          | 24           |
# | policy_entropy     | 1.4096978    |
# | policy_loss        | -0.013101591 |
# | serial_timesteps   | 3072         |
# | time_elapsed       | 148          |
# | total_timesteps    | 3072         |
# | value_loss         | 0.9849613    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0010537135 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.799        |
# | fps                | 21           |
# | n_updates          | 25           |
# | policy_entropy     | 1.4751995    |
# | policy_loss        | -0.004433347 |
# | serial_timesteps   | 3200         |
# | time_elapsed       | 154          |
# | total_timesteps    | 3200         |
# | value_loss         | 0.7137679    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0012465097 |
# | clipfrac           | 0.001953125  |
# | explained_variance | 0.822        |
# | fps                | 21           |
# | n_updates          | 26           |
# | policy_entropy     | 1.4803351    |
# | policy_loss        | -0.006603705 |
# | serial_timesteps   | 3328         |
# | time_elapsed       | 160          |
# | total_timesteps    | 3328         |
# | value_loss         | 0.6110946    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0007980744  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.837         |
# | fps                | 21            |
# | n_updates          | 27            |
# | policy_entropy     | 1.4990233     |
# | policy_loss        | -0.0039432077 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 166           |
# | total_timesteps    | 3456          |
# | value_loss         | 0.5674269     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029147716 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.748         |
# | fps                | 21            |
# | n_updates          | 28            |
# | policy_entropy     | 1.5216125     |
# | policy_loss        | -0.0019713524 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 172           |
# | total_timesteps    | 3584          |
# | value_loss         | 0.91908836    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048713412 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.796         |
# | fps                | 21            |
# | n_updates          | 29            |
# | policy_entropy     | 1.511496      |
# | policy_loss        | -0.00511436   |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 178           |
# | total_timesteps    | 3712          |
# | value_loss         | 0.8093783     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00056100293 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.655         |
# | fps                | 21            |
# | n_updates          | 30            |
# | policy_entropy     | 1.4975202     |
# | policy_loss        | -0.0046929317 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 184           |
# | total_timesteps    | 3840          |
# | value_loss         | 1.2314876     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025232456 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.782         |
# | fps                | 20            |
# | n_updates          | 31            |
# | policy_entropy     | 1.4853427     |
# | policy_loss        | -0.0040411563 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 190           |
# | total_timesteps    | 3968          |
# | value_loss         | 0.8322        |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00075726584 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.758         |
# | fps                | 21            |
# | n_updates          | 32            |
# | policy_entropy     | 1.4916136     |
# | policy_loss        | -0.005915867  |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 196           |
# | total_timesteps    | 4096          |
# | value_loss         | 0.855828      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004817655 |
# | clipfrac           | 0.00390625   |
# | explained_variance | 0.901        |
# | fps                | 20           |
# | n_updates          | 33           |
# | policy_entropy     | 1.4688311    |
# | policy_loss        | -0.004187379 |
# | serial_timesteps   | 4224         |
# | time_elapsed       | 202          |
# | total_timesteps    | 4224         |
# | value_loss         | 0.37198472   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0005901613  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.682         |
# | fps                | 20            |
# | n_updates          | 34            |
# | policy_entropy     | 1.477064      |
# | policy_loss        | -0.0058206245 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 208           |
# | total_timesteps    | 4352          |
# | value_loss         | 1.2320367     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020010473 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.881         |
# | fps                | 18            |
# | n_updates          | 35            |
# | policy_entropy     | 1.4819129     |
# | policy_loss        | 0.00066016265 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 214           |
# | total_timesteps    | 4480          |
# | value_loss         | 0.41623935    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014485189 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.934         |
# | fps                | 20            |
# | n_updates          | 36            |
# | policy_entropy     | 1.4904367     |
# | policy_loss        | -0.0020862904 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 221           |
# | total_timesteps    | 4608          |
# | value_loss         | 0.25646302    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005342818  |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.745         |
# | fps                | 21            |
# | n_updates          | 37            |
# | policy_entropy     | 1.4924304     |
# | policy_loss        | -0.0070768017 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 227           |
# | total_timesteps    | 4736          |
# | value_loss         | 1.0048349     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000700528   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.701         |
# | fps                | 21            |
# | n_updates          | 38            |
# | policy_entropy     | 1.4756799     |
# | policy_loss        | -0.0015913222 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 234           |
# | total_timesteps    | 4864          |
# | value_loss         | 1.103058      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001386246  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.693         |
# | fps                | 21            |
# | n_updates          | 39            |
# | policy_entropy     | 1.4908746     |
# | policy_loss        | -0.0016501204 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 240           |
# | total_timesteps    | 4992          |
# | value_loss         | 1.0799809     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023923318 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.812         |
# | fps                | 21            |
# | n_updates          | 40            |
# | policy_entropy     | 1.4834692     |
# | policy_loss        | -0.0021443465 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 246           |
# | total_timesteps    | 5120          |
# | value_loss         | 0.67721236    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008723724 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.9          |
# | fps                | 20           |
# | n_updates          | 41           |
# | policy_entropy     | 1.4847715    |
# | policy_loss        | -0.007593943 |
# | serial_timesteps   | 5248         |
# | time_elapsed       | 252          |
# | total_timesteps    | 5248         |
# | value_loss         | 0.34017095   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0013518181 |
# | clipfrac           | 0.001953125  |
# | explained_variance | 0.853        |
# | fps                | 20           |
# | n_updates          | 42           |
# | policy_entropy     | 1.449583     |
# | policy_loss        | -0.004163587 |
# | serial_timesteps   | 5376         |
# | time_elapsed       | 258          |
# | total_timesteps    | 5376         |
# | value_loss         | 0.52143943   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00022973446 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.928         |
# | fps                | 19            |
# | n_updates          | 43            |
# | policy_entropy     | 1.4213274     |
# | policy_loss        | -0.0024814634 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 264           |
# | total_timesteps    | 5504          |
# | value_loss         | 0.24155143    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00079744554 |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.941         |
# | fps                | 20            |
# | n_updates          | 44            |
# | policy_entropy     | 1.427737      |
# | policy_loss        | -0.00406306   |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 270           |
# | total_timesteps    | 5632          |
# | value_loss         | 0.20529687    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005872547  |
# | clipfrac           | 0.005859375   |
# | explained_variance | 0.916         |
# | fps                | 21            |
# | n_updates          | 45            |
# | policy_entropy     | 1.4356691     |
# | policy_loss        | -0.0030564745 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 276           |
# | total_timesteps    | 5760          |
# | value_loss         | 0.29124314    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000573296   |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.909         |
# | fps                | 21            |
# | n_updates          | 46            |
# | policy_entropy     | 1.4701973     |
# | policy_loss        | -0.0059052785 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 283           |
# | total_timesteps    | 5888          |
# | value_loss         | 0.3226201     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012997529  |
# | clipfrac           | 0.009765625   |
# | explained_variance | 0.704         |
# | fps                | 21            |
# | n_updates          | 47            |
# | policy_entropy     | 1.4869859     |
# | policy_loss        | -0.0051628174 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 289           |
# | total_timesteps    | 6016          |
# | value_loss         | 1.1016351     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005779101  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.711         |
# | fps                | 21            |
# | n_updates          | 48            |
# | policy_entropy     | 1.4949968     |
# | policy_loss        | -0.0011841279 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 295           |
# | total_timesteps    | 6144          |
# | value_loss         | 1.0956354     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00060062355 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.749         |
# | fps                | 20            |
# | n_updates          | 49            |
# | policy_entropy     | 1.5162363     |
# | policy_loss        | -0.007431914  |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 301           |
# | total_timesteps    | 6272          |
# | value_loss         | 0.89812773    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00039523753 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.872         |
# | fps                | 20            |
# | n_updates          | 50            |
# | policy_entropy     | 1.4938697     |
# | policy_loss        | -0.0015694884 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 307           |
# | total_timesteps    | 6400          |
# | value_loss         | 0.45587602    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020002262 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.846         |
# | fps                | 20            |
# | n_updates          | 51            |
# | policy_entropy     | 1.4854605     |
# | policy_loss        | -0.0026897886 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 313           |
# | total_timesteps    | 6528          |
# | value_loss         | 0.5614205     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00082481117 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.872         |
# | fps                | 19            |
# | n_updates          | 52            |
# | policy_entropy     | 1.4968927     |
# | policy_loss        | -0.0061628884 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 319           |
# | total_timesteps    | 6656          |
# | value_loss         | 0.45726168    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010524709  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.899         |
# | fps                | 19            |
# | n_updates          | 53            |
# | policy_entropy     | 1.4328146     |
# | policy_loss        | -0.0066814683 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 326           |
# | total_timesteps    | 6784          |
# | value_loss         | 0.35185385    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00049815676 |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.933         |
# | fps                | 20            |
# | n_updates          | 54            |
# | policy_entropy     | 1.4412676     |
# | policy_loss        | -0.0043798424 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 332           |
# | total_timesteps    | 6912          |
# | value_loss         | 0.23964562    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00061091455 |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.901         |
# | fps                | 19            |
# | n_updates          | 55            |
# | policy_entropy     | 1.493047      |
# | policy_loss        | -0.00132478   |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 339           |
# | total_timesteps    | 7040          |
# | value_loss         | 0.3543867     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010980282  |
# | clipfrac           | 0.01953125    |
# | explained_variance | 0.888         |
# | fps                | 19            |
# | n_updates          | 56            |
# | policy_entropy     | 1.4726837     |
# | policy_loss        | -0.0069908053 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 345           |
# | total_timesteps    | 7168          |
# | value_loss         | 0.41092196    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020642915 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.832         |
# | fps                | 20            |
# | n_updates          | 57            |
# | policy_entropy     | 1.5073097     |
# | policy_loss        | -0.0019877618 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 351           |
# | total_timesteps    | 7296          |
# | value_loss         | 0.62774926    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025550005 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.88          |
# | fps                | 20            |
# | n_updates          | 58            |
# | policy_entropy     | 1.510281      |
# | policy_loss        | -0.00546543   |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 358           |
# | total_timesteps    | 7424          |
# | value_loss         | 0.46129966    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029239056 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.745         |
# | fps                | 19            |
# | n_updates          | 59            |
# | policy_entropy     | 1.4890621     |
# | policy_loss        | -0.0020790866 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 364           |
# | total_timesteps    | 7552          |
# | value_loss         | 0.8877453     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003871088 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.633        |
# | fps                | 20           |
# | n_updates          | 60           |
# | policy_entropy     | 1.4920444    |
# | policy_loss        | -0.00467692  |
# | serial_timesteps   | 7680         |
# | time_elapsed       | 371          |
# | total_timesteps    | 7680         |
# | value_loss         | 1.4032578    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0002963883  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.889         |
# | fps                | 19            |
# | n_updates          | 61            |
# | policy_entropy     | 1.477128      |
# | policy_loss        | -0.0031183553 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 377           |
# | total_timesteps    | 7808          |
# | value_loss         | 0.38957304    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024072255 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.908         |
# | fps                | 20            |
# | n_updates          | 62            |
# | policy_entropy     | 1.4508443     |
# | policy_loss        | -0.0037288994 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 383           |
# | total_timesteps    | 7936          |
# | value_loss         | 0.32314852    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007457528 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.735        |
# | fps                | 19           |
# | n_updates          | 63           |
# | policy_entropy     | 1.4753739    |
# | policy_loss        | -0.004592479 |
# | serial_timesteps   | 8064         |
# | time_elapsed       | 389          |
# | total_timesteps    | 8064         |
# | value_loss         | 0.93445647   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00014911461 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.722         |
# | fps                | 18            |
# | n_updates          | 64            |
# | policy_entropy     | 1.4805279     |
# | policy_loss        | -0.0023898808 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 396           |
# | total_timesteps    | 8192          |
# | value_loss         | 1.060949      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026727104 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.902         |
# | fps                | 19            |
# | n_updates          | 65            |
# | policy_entropy     | 1.4657242     |
# | policy_loss        | -0.0013278029 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 403           |
# | total_timesteps    | 8320          |
# | value_loss         | 0.3767748     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014083137 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.912         |
# | fps                | 19            |
# | n_updates          | 66            |
# | policy_entropy     | 1.4364126     |
# | policy_loss        | -0.005466369  |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 409           |
# | total_timesteps    | 8448          |
# | value_loss         | 0.3011113     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003868214  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.936         |
# | fps                | 19            |
# | n_updates          | 67            |
# | policy_entropy     | 1.4564753     |
# | policy_loss        | -0.0036724957 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 416           |
# | total_timesteps    | 8576          |
# | value_loss         | 0.22198918    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017126879 |
# | clipfrac           | 0.013671875  |
# | explained_variance | 0.88         |
# | fps                | 20           |
# | n_updates          | 68           |
# | policy_entropy     | 1.4752792    |
# | policy_loss        | -0.006944705 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 422          |
# | total_timesteps    | 8704         |
# | value_loss         | 0.45364136   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012682696  |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.937         |
# | fps                | 19            |
# | n_updates          | 69            |
# | policy_entropy     | 1.4816322     |
# | policy_loss        | -0.0058230357 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 428           |
# | total_timesteps    | 8832          |
# | value_loss         | 0.21700758    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00084021664 |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.696         |
# | fps                | 19            |
# | n_updates          | 70            |
# | policy_entropy     | 1.4758571     |
# | policy_loss        | -0.004927967  |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 435           |
# | total_timesteps    | 8960          |
# | value_loss         | 1.2667264     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00096877146 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.815         |
# | fps                | 19            |
# | n_updates          | 71            |
# | policy_entropy     | 1.4385847     |
# | policy_loss        | -0.0075538177 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 441           |
# | total_timesteps    | 9088          |
# | value_loss         | 0.66129136    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0025546793 |
# | clipfrac           | 0.015625     |
# | explained_variance | 0.854        |
# | fps                | 19           |
# | n_updates          | 72           |
# | policy_entropy     | 1.4192648    |
# | policy_loss        | -0.009252803 |
# | serial_timesteps   | 9216         |
# | time_elapsed       | 448          |
# | total_timesteps    | 9216         |
# | value_loss         | 0.5206471    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0011113258  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.903         |
# | fps                | 20            |
# | n_updates          | 73            |
# | policy_entropy     | 1.3861815     |
# | policy_loss        | -0.0044080205 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 454           |
# | total_timesteps    | 9344          |
# | value_loss         | 0.3383909     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018045022 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.932         |
# | fps                | 20            |
# | n_updates          | 74            |
# | policy_entropy     | 1.3834348     |
# | policy_loss        | -0.0034091878 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 461           |
# | total_timesteps    | 9472          |
# | value_loss         | 0.2471166     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00042213767 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.885         |
# | fps                | 19            |
# | n_updates          | 75            |
# | policy_entropy     | 1.3437502     |
# | policy_loss        | -0.0031891542 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 467           |
# | total_timesteps    | 9600          |
# | value_loss         | 0.439012      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003420487  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.876         |
# | fps                | 20            |
# | n_updates          | 76            |
# | policy_entropy     | 1.3508036     |
# | policy_loss        | -0.0011586121 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 473           |
# | total_timesteps    | 9728          |
# | value_loss         | 0.4624552     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019596709 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.929         |
# | fps                | 20            |
# | n_updates          | 77            |
# | policy_entropy     | 1.3352973     |
# | policy_loss        | -0.0018872045 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 479           |
# | total_timesteps    | 9856          |
# | value_loss         | 0.24490762    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004380248  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.821         |
# | fps                | 20            |
# | n_updates          | 78            |
# | policy_entropy     | 1.3283314     |
# | policy_loss        | -0.0039768834 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 486           |
# | total_timesteps    | 9984          |
# | value_loss         | 0.68121606    |
# --------------------------------------

# %% [markdown]
# ## Performance of PPO on roundabout env.
#
# I used the average of rewards and the number of crashes for evaluation of the algorithm on the environment.

# %%
#Visualising the performance of the model and noting the performance for comparison


crashcount = 0
for i in range(100):
    done = False
    obs = env.reset()
    total_reward = []
    while not done:
        env.render()
        #render the next actions, rewards and states.
        action, _states = ppo_roundabout.predict(obs)
        next_state, reward, done, info = env.step(action)
        if info['crashed']==True : crashcount +=1
        total_reward.append(reward)
        print(info)
        print(done)
      
    
rewards_average = Average(total_reward) 
  
print("The average of rewards: ",rewards_average)   
print("Number of Crashes: ", crashcount)
env.close()
# Out:
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 2}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 6.632894292898015, 'crashed': False, 'action': 3}
# False
# {'speed': 7.76637771916602, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 2}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 6.63309335676719, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1335176138483234, 'crashed': False, 'action': 4}
# False
# {'speed': 0.1937048239481749, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0331018754030709, 'crashed': False, 'action': 4}
# False
# {'speed': 0.005656721050445239, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0009666670740831121, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 0}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 2}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 0}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 0}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 6.632894292898015, 'crashed': False, 'action': 3}
# False
# {'speed': 7.76637771916602, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 6.672817427093691, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1403059900985835, 'crashed': False, 'action': 4}
# False
# {'speed': 0.19486487758155982, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03330011492055168, 'crashed': False, 'action': 4}
# False
# {'speed': 0.005690597851620667, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0009724562208307615, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00016618132682897672, 'crashed': False, 'action': 4}
# False
# {'speed': 2.839843356963346e-05, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 1}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 2}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 2}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 2}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# ...
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 1}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 0}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 6.6329281696991895, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1334893853218897, 'crashed': False, 'action': 4}
# False
# {'speed': 0.1937000000251265, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03310105105137717, 'crashed': False, 'action': 4}
# False
# {'speed': 0.005656580178439586, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 2}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 0}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 0}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 0}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 2}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 6.63309335676719, 'crashed': False, 'action': 3}
# False
# {'speed': 1.1335176138483234, 'crashed': False, 'action': 4}
# False
# {'speed': 0.1937048239481749, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0331018754030709, 'crashed': False, 'action': 0}
# True
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 2}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 1}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 2}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 2}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 1}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 2}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 0}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 0}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 0}
# False
# {'speed': 8.0, 'crashed': False, 'action': 2}
# False
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 2}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 1}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 1}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 1}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 0}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 0}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# The average of rewards:  0.8884982420894023
# Number of Crashes:  0

# %% [markdown]
# The environment always through random environments at the agent. So, the performance metric used that is the reward function keeps changing after the code snippet is completed
#
# After running the code a few times, I aw that the reward is anywhere from 0.89 to 0.99, which is a pretty good reward. The number of crashed out of 100, were only about 0-25.
#
# The performance of PPO is better than agent taking random actions

# %% [markdown]
# # DQN WITH ROUNDABOUT

# %% [markdown]
# ## Creating the DQN model
#
#
# For more information on the algorithm look at the report attached with the code.
#
# Number of timesteps: 10000

# %%
# creating the dqn policy with the roundabout environment
dqn_roundabout = DQN('MlpPolicy', env, verbose=1)
# we take actions based on DQN policy
dqn_roundabout.learn(total_timesteps=10000)
# Out:
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\tf_util.py:322: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# --------------------------------------
# | % time spent exploring  | 7        |
# | episodes                | 100      |
# | mean 100 episode reward | 8.7      |
# | steps                   | 948      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 200      |
# | mean 100 episode reward | 8.2      |
# | steps                   | 1852     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 300      |
# | mean 100 episode reward | 8.5      |
# | steps                   | 2792     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 400      |
# | mean 100 episode reward | 9.9      |
# | steps                   | 3860     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 500      |
# | mean 100 episode reward | 9.9      |
# | steps                   | 4934     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 600      |
# | mean 100 episode reward | 10       |
# | steps                   | 6010     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 700      |
# | mean 100 episode reward | 10.2     |
# | steps                   | 7103     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 800      |
# | mean 100 episode reward | 10       |
# | steps                   | 8181     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 900      |
# | mean 100 episode reward | 10.1     |
# | steps                   | 9271     |
# --------------------------------------

# %% [markdown]
# ## Performance of DQN on roundabout env

# %%
#Visualising the performance of the model and noting the performance for comparison
crashcount = 0
for i in range(100):
    done = False
    obs = env.reset()
    total_reward = []
    while not done:
        env.render()
        action, _states = dqn_roundabout.predict(obs)
        next_state, reward, done, info = env.step(action)
        if info['crashed']==True : crashcount +=1
        total_reward.append(reward)
        print(info)
        print(done)

        
rewards_average = Average(total_reward) 
  
print("The average of rewards: ",rewards_average) 
print("Number of Crashes: ", crashcount)       
env.close()
# Out:
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 4.012894602048116, 'crashed': True, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 3.2626319371911205, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 3.7453682952449086, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 4.299529930765839, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 7.466666666666667, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': True, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 7.466666666666667, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 1.3671058770091211, 'crashed': False, 'action': 4}
# False
# {'speed': 0.23362230986910987, 'crashed': False, 'action': 4}
# False
# {'speed': 0.03992330410281328, 'crashed': False, 'action': 4}
# False
# {'speed': 0.006822422958572302, 'crashed': False, 'action': 4}
# False
# {'speed': 0.0011658718152632692, 'crashed': False, 'action': 4}
# False
# {'speed': 0.00019923377631071346, 'crashed': False, 'action': 4}
# False
# {'speed': 3.404670831163714e-05, 'crashed': False, 'action': 4}
# False
# {'speed': 5.818181878206805e-06, 'crashed': False, 'action': 4}
# False
# {'speed': 9.942588299005616e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 1.699071362031588e-07, 'crashed': False, 'action': 4}
# False
# {'speed': 2.9035130556140955e-08, 'crashed': False, 'action': 4}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': True, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# False
# {'speed': 8.0, 'crashed': False, 'action': 1}
# True
# The average of rewards:  0.9447513812154696
# Number of Crashes:  8

# %% [markdown]
# The environment always through random environments at the agent. So, the performance metric used that is the reward function keeps changing after the code snippet is completed
#
# After running the code a few times, I aw that the reward is anywhere from 0.81 to 0.99
#
# The number of crashed out of 100, were only about 0-25.

# %% [markdown]
# ### For three different environment, I ran this code 5 times, so after running the loop 100 times in the same environment (chosen randomly), I also run the code in 100 loops, in 5 randomly selected environment to test thoroughly.
#
#
#
# ### The detailed results of Five runs can be found in the report in the report.

# %% [markdown]
# ## Parking setup

# %% [markdown]
# #### Setting up the environment for parking

# %%
env = gym.make('parking-v0')

# %% [markdown]
# #### Using the env.config to look at the configurations available and the default values for this configuration.

# %%
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'ContinuousAction'},
#  'centering_position': [0.5, 0.5],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'duration': 100,
#  'manual_control': False,
#  'observation': {'features': ['x', 'y', 'vx', 'vy', 'cos_h', 'sin_h'],
#                  'normalize': False,
#                  'scales': [100, 100, 5, 5, 1, 1],
#                  'type': 'KinematicsGoal'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 5,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_weights': [1, 0.3, 0, 0, 0.02, 0.02],
#  'scaling': 7,
#  'screen_height': 300,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'steering_range': 0.7853981633974483,
#  'success_goal_reward': 0.12}

# %% [markdown]
# #### Changing the rewards in the parking environment was more important in parking more than any other environment. The magnitude of results changed heavily when the rewards values changed and I had to curate it exactly as needed. Even if the rewards for sccessful parking was high the accuracy (average_rewards) was low.
#
# #### In this case, "Testing" the environment with different values became very crucial.

# %%
env.config['controlled_vehicles'] = 2
env.config["success_goal_reward"] = 20
env.reset()
# Out:
# {'observation': array([ 0.        ,  0.        , -0.        , -0.        , -0.29982512,
#         -0.95399418]),
#  'achieved_goal': array([ 0.        ,  0.        , -0.        , -0.        , -0.29982512,
#         -0.95399418]),
#  'desired_goal': array([2.200000e-01, 1.400000e-01, 0.000000e+00, 0.000000e+00,
#         6.123234e-17, 1.000000e+00])}

# %% [markdown]
# ## GREEDY WITH PARKING

# %% [markdown]
# ### Performance of agents taking random actions
#
# There are no other cars than the agent in this environment, so we will not look at the number of crashes. We will only look at the reward function.
#
# Reward function: We will look at the reward function to evaluate the performance of the agent taking greedy actions. I take the reward from each loop and then find the average of all the rewards.

# %%
# Writing a function for calculating the average of the rewards.

def Average(l): 
    avg = mean(l) 
    return avg


for i in range(100):
    done = False
    env.reset()
    
    total_reward = []
    while not done:
        env.render()
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        total_reward.append(reward)
        print(info)
        print(done)
        
rewards_average = Average(total_reward)      

print("The average of rewards: ",rewards_average)
   
env.close()
# Out:
# {'speed': -0.9997962117195129, 'crashed': False, 'action': array([-0.9997962 ,  0.88134676], dtype=float32), 'is_success': True}
# True
# {'speed': -0.045205067843198776, 'crashed': False, 'action': array([-0.04520507,  0.485113  ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.3784888684749603, 'crashed': False, 'action': array([-0.37848887,  0.9909345 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.387527197599411, 'crashed': False, 'action': array([0.3875272 , 0.38862443], dtype=float32), 'is_success': True}
# True
# {'speed': -0.13067419826984406, 'crashed': False, 'action': array([-0.1306742 , -0.08394579], dtype=float32), 'is_success': True}
# True
# {'speed': -0.6677389740943909, 'crashed': False, 'action': array([-0.667739  ,  0.43124896], dtype=float32), 'is_success': True}
# True
# {'speed': 0.5656623840332031, 'crashed': False, 'action': array([0.5656624, 0.9572386], dtype=float32), 'is_success': True}
# True
# {'speed': -0.4537866711616516, 'crashed': False, 'action': array([-0.45378667, -0.8972351 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.7973894476890564, 'crashed': False, 'action': array([-0.79738945, -0.91754687], dtype=float32), 'is_success': True}
# True
# {'speed': -0.83359295129776, 'crashed': False, 'action': array([-0.83359295,  0.8880208 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.8652254939079285, 'crashed': False, 'action': array([ 0.8652255, -0.8141328], dtype=float32), 'is_success': True}
# True
# {'speed': 0.18403920531272888, 'crashed': False, 'action': array([ 0.1840392 , -0.10289678], dtype=float32), 'is_success': True}
# True
# {'speed': 0.00252361549064517, 'crashed': False, 'action': array([0.00252362, 0.85347635], dtype=float32), 'is_success': True}
# True
# {'speed': 0.4919983744621277, 'crashed': False, 'action': array([ 0.49199837, -0.40142864], dtype=float32), 'is_success': True}
# True
# {'speed': 0.6483355760574341, 'crashed': False, 'action': array([ 0.6483356 , -0.46249026], dtype=float32), 'is_success': True}
# True
# {'speed': 0.11298495531082153, 'crashed': False, 'action': array([0.11298496, 0.22631806], dtype=float32), 'is_success': True}
# True
# {'speed': 0.44325342774391174, 'crashed': False, 'action': array([0.44325343, 0.68513894], dtype=float32), 'is_success': True}
# True
# {'speed': 0.42030465602874756, 'crashed': False, 'action': array([0.42030466, 0.5377759 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.36821070313453674, 'crashed': False, 'action': array([0.3682107 , 0.53090304], dtype=float32), 'is_success': True}
# True
# {'speed': -0.6953635215759277, 'crashed': False, 'action': array([-0.6953635, -0.0391164], dtype=float32), 'is_success': True}
# True
# {'speed': 0.49027055501937866, 'crashed': False, 'action': array([0.49027056, 0.35460588], dtype=float32), 'is_success': True}
# True
# {'speed': 0.2959855794906616, 'crashed': False, 'action': array([ 0.29598558, -0.44917297], dtype=float32), 'is_success': True}
# True
# {'speed': -0.7384030818939209, 'crashed': False, 'action': array([-0.7384031 ,  0.04102321], dtype=float32), 'is_success': True}
# True
# {'speed': -0.2993753254413605, 'crashed': False, 'action': array([-0.29937533, -0.45311502], dtype=float32), 'is_success': True}
# True
# {'speed': 0.020283954218029976, 'crashed': False, 'action': array([0.02028395, 0.10691686], dtype=float32), 'is_success': True}
# True
# {'speed': -0.4051690399646759, 'crashed': False, 'action': array([-0.40516904, -0.62707496], dtype=float32), 'is_success': True}
# True
# {'speed': -0.9662176370620728, 'crashed': False, 'action': array([-0.96621764,  0.53411275], dtype=float32), 'is_success': True}
# True
# {'speed': 0.036698076874017715, 'crashed': False, 'action': array([0.03669808, 0.32268366], dtype=float32), 'is_success': True}
# True
# {'speed': 0.1379116326570511, 'crashed': False, 'action': array([ 0.13791163, -0.99453574], dtype=float32), 'is_success': True}
# True
# {'speed': -0.25696292519569397, 'crashed': False, 'action': array([-0.25696293,  0.12275098], dtype=float32), 'is_success': True}
# True
# {'speed': 0.212436705827713, 'crashed': False, 'action': array([0.2124367 , 0.16018659], dtype=float32), 'is_success': True}
# True
# {'speed': 0.9241576790809631, 'crashed': False, 'action': array([ 0.9241577 , -0.03739151], dtype=float32), 'is_success': True}
# True
# {'speed': 0.8959531188011169, 'crashed': False, 'action': array([0.8959531 , 0.23120892], dtype=float32), 'is_success': True}
# True
# {'speed': -0.8042184710502625, 'crashed': False, 'action': array([-0.8042185 , -0.11283539], dtype=float32), 'is_success': True}
# True
# {'speed': -0.9941456913948059, 'crashed': False, 'action': array([-0.9941457, -0.5235406], dtype=float32), 'is_success': True}
# True
# {'speed': 0.7447614073753357, 'crashed': False, 'action': array([ 0.7447614 , -0.71060026], dtype=float32), 'is_success': True}
# True
# {'speed': 0.029959341511130333, 'crashed': False, 'action': array([ 0.02995934, -0.6838962 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.8549726009368896, 'crashed': False, 'action': array([-0.8549726,  0.6446827], dtype=float32), 'is_success': True}
# True
# {'speed': -0.43352165818214417, 'crashed': False, 'action': array([-0.43352166, -0.35927385], dtype=float32), 'is_success': True}
# True
# {'speed': -0.5061050653457642, 'crashed': False, 'action': array([-0.50610507,  0.28978172], dtype=float32), 'is_success': True}
# True
# {'speed': 0.6355966329574585, 'crashed': False, 'action': array([ 0.63559663, -0.1610244 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.14174021780490875, 'crashed': False, 'action': array([-0.14174022,  0.6935585 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.10842236876487732, 'crashed': False, 'action': array([-0.10842237, -0.48243076], dtype=float32), 'is_success': True}
# True
# {'speed': 0.5705937743186951, 'crashed': False, 'action': array([0.5705938, 0.5231591], dtype=float32), 'is_success': True}
# True
# {'speed': -0.4311129152774811, 'crashed': False, 'action': array([-0.43111292,  0.26619244], dtype=float32), 'is_success': True}
# True
# {'speed': 0.03625698760151863, 'crashed': False, 'action': array([0.03625699, 0.9013709 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.7182679176330566, 'crashed': False, 'action': array([-0.7182679, -0.6179882], dtype=float32), 'is_success': True}
# True
# {'speed': -0.43046048283576965, 'crashed': False, 'action': array([-0.43046048,  0.7008888 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.8679883480072021, 'crashed': False, 'action': array([0.86798835, 0.35216826], dtype=float32), 'is_success': True}
# True
# {'speed': 0.2902612090110779, 'crashed': False, 'action': array([ 0.2902612 , -0.10717522], dtype=float32), 'is_success': True}
# True
# {'speed': -0.1635686606168747, 'crashed': False, 'action': array([-0.16356866,  0.8972129 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.584326446056366, 'crashed': False, 'action': array([0.58432645, 0.22066677], dtype=float32), 'is_success': True}
# True
# {'speed': -0.44265738129615784, 'crashed': False, 'action': array([-0.44265738, -0.994039  ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.5228798985481262, 'crashed': False, 'action': array([ 0.5228799 , -0.07009394], dtype=float32), 'is_success': True}
# True
# {'speed': -0.6456179618835449, 'crashed': False, 'action': array([-0.64561796,  0.1273933 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.5827594995498657, 'crashed': False, 'action': array([ 0.5827595, -0.7693075], dtype=float32), 'is_success': True}
# True
# {'speed': 0.869127631187439, 'crashed': False, 'action': array([ 0.86912763, -0.5357339 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.8981265425682068, 'crashed': False, 'action': array([0.89812654, 0.3806255 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.580987274646759, 'crashed': False, 'action': array([0.5809873, 0.8202542], dtype=float32), 'is_success': True}
# True
# {'speed': 0.8548559546470642, 'crashed': False, 'action': array([ 0.85485595, -0.3944817 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.75778728723526, 'crashed': False, 'action': array([ 0.7577873, -0.3474409], dtype=float32), 'is_success': True}
# True
# {'speed': 0.05767260491847992, 'crashed': False, 'action': array([ 0.0576726, -0.9798338], dtype=float32), 'is_success': True}
# True
# {'speed': 0.830441951751709, 'crashed': False, 'action': array([0.83044195, 0.4656274 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.2905200719833374, 'crashed': False, 'action': array([0.29052007, 0.7559798 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.8905428647994995, 'crashed': False, 'action': array([-0.89054286, -0.13423018], dtype=float32), 'is_success': True}
# True
# {'speed': 0.3985496163368225, 'crashed': False, 'action': array([0.39854962, 0.69164515], dtype=float32), 'is_success': True}
# True
# {'speed': -0.23653414845466614, 'crashed': False, 'action': array([-0.23653415,  0.9503188 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.6692821979522705, 'crashed': False, 'action': array([0.6692822 , 0.46639025], dtype=float32), 'is_success': True}
# True
# {'speed': -0.9933217763900757, 'crashed': False, 'action': array([-0.9933218 , -0.43055972], dtype=float32), 'is_success': True}
# True
# {'speed': -0.5180860757827759, 'crashed': False, 'action': array([-0.5180861 ,  0.35060734], dtype=float32), 'is_success': True}
# True
# {'speed': 0.2310871034860611, 'crashed': False, 'action': array([ 0.2310871 , -0.26572028], dtype=float32), 'is_success': True}
# True
# {'speed': -0.6680505275726318, 'crashed': False, 'action': array([-0.6680505 , -0.77551705], dtype=float32), 'is_success': True}
# True
# {'speed': 0.5596551895141602, 'crashed': False, 'action': array([0.5596552 , 0.06709292], dtype=float32), 'is_success': True}
# True
# {'speed': 0.16293476521968842, 'crashed': False, 'action': array([0.16293477, 0.29923415], dtype=float32), 'is_success': True}
# True
# {'speed': -0.2775306701660156, 'crashed': False, 'action': array([-0.27753067,  0.7103742 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.01667071506381035, 'crashed': False, 'action': array([ 0.01667072, -0.08081238], dtype=float32), 'is_success': True}
# True
# {'speed': -0.49990174174308777, 'crashed': False, 'action': array([-0.49990174,  0.97471637], dtype=float32), 'is_success': True}
# True
# {'speed': -0.9840088486671448, 'crashed': False, 'action': array([-0.98400885,  0.73639184], dtype=float32), 'is_success': True}
# True
# {'speed': -0.8715781569480896, 'crashed': False, 'action': array([-0.87157816,  0.6644912 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.9393556118011475, 'crashed': False, 'action': array([ 0.9393556 , -0.63431853], dtype=float32), 'is_success': True}
# True
# {'speed': 0.6714004278182983, 'crashed': False, 'action': array([0.6714004, 0.1172791], dtype=float32), 'is_success': True}
# True
# {'speed': 0.5568615198135376, 'crashed': False, 'action': array([ 0.5568615 , -0.70275986], dtype=float32), 'is_success': True}
# True
# {'speed': -0.794152557849884, 'crashed': False, 'action': array([-0.79415256, -0.75244683], dtype=float32), 'is_success': True}
# True
# {'speed': -0.3450990319252014, 'crashed': False, 'action': array([-0.34509903, -0.56519645], dtype=float32), 'is_success': True}
# True
# {'speed': 0.08069739490747452, 'crashed': False, 'action': array([0.08069739, 0.23985235], dtype=float32), 'is_success': True}
# True
# {'speed': 0.006714539136737585, 'crashed': False, 'action': array([ 0.00671454, -0.03936942], dtype=float32), 'is_success': True}
# True
# {'speed': 0.2430160939693451, 'crashed': False, 'action': array([ 0.2430161 , -0.62896293], dtype=float32), 'is_success': True}
# True
# {'speed': -0.9244090914726257, 'crashed': False, 'action': array([-0.9244091 , -0.69389176], dtype=float32), 'is_success': True}
# True
# {'speed': 0.9888890385627747, 'crashed': False, 'action': array([0.98888904, 0.58848757], dtype=float32), 'is_success': True}
# True
# {'speed': -0.8258382678031921, 'crashed': False, 'action': array([-0.82583827, -0.20644586], dtype=float32), 'is_success': True}
# True
# {'speed': 0.9110013246536255, 'crashed': False, 'action': array([ 0.9110013, -0.756264 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.3143707513809204, 'crashed': False, 'action': array([-0.31437075, -0.8715316 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.3973037004470825, 'crashed': False, 'action': array([-0.3973037, -0.5151243], dtype=float32), 'is_success': True}
# True
# {'speed': -0.3845521807670593, 'crashed': False, 'action': array([-0.38455218,  0.15662232], dtype=float32), 'is_success': True}
# True
# {'speed': 0.07867234200239182, 'crashed': False, 'action': array([ 0.07867234, -0.85974395], dtype=float32), 'is_success': True}
# True
# {'speed': 0.732271134853363, 'crashed': False, 'action': array([ 0.73227113, -0.9593778 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.28771892189979553, 'crashed': False, 'action': array([-0.28771892, -0.8644214 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.6716861724853516, 'crashed': False, 'action': array([ 0.6716862 , -0.55163276], dtype=float32), 'is_success': True}
# True
# {'speed': 0.9599997401237488, 'crashed': False, 'action': array([0.95999974, 0.11135916], dtype=float32), 'is_success': True}
# True
# {'speed': -0.2608921527862549, 'crashed': False, 'action': array([-0.26089215,  0.88139397], dtype=float32), 'is_success': True}
# True
# The average of rewards:  -0.5895596781202299

# %% [markdown]
# The reward for the agent taking the random actions in the parking environment is -0.371 to -0.59 in the very best case.

# %% [markdown]
# #### Let us look at an intelligent agent that which takes action based on policy and not randomly.

# %% [markdown]
# ## HER WITH PARKING
#
# More information on the algorithm can be found in the report.

# %% [markdown]
# ### Creating an HER model

# %%
her_parking = HER('MlpPolicy', env, SAC, n_sampled_goal=4,
            goal_selection_strategy='future',
            verbose=1, buffer_size=int(1e6),
            learning_rate=1e-3,
            gamma=0.9, batch_size=256,
            policy_kwargs=dict(layers=[256, 256, 256]))
# Out:
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\common\tf_layers.py:57: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\sac\policies.py:216: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
# C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\gym\spaces\box.py:74: UserWarning: WARN: Box bound precision lowered by casting to float32
#   "Box bound precision lowered by casting to {}".format(self.dtype)
# WARNING:tensorflow:From C:\Users\shrit\anaconda3\envs\intelcar\lib\site-packages\stable_baselines\sac\sac.py:267: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %%
her_parking = HER('MlpPolicy', env, SAC, n_sampled_goal= 4, goal_selection_strategy='future', verbose=2)

# %% [markdown]
# The next step was a very difficult step for me. One of the disadvantages of the HER policy is that it takes a long time to train. I had to experiment with a few values of timestep.

# %%
her_parking.learn(10000)
# Out:
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 1.0         |
# | ent_coef_loss           | 0.0         |
# | entropy                 | 2.4352427   |
# | episodes                | 100         |
# | fps                     | 71          |
# | mean 100 episode reward | -0.5        |
# | n_updates               | 1           |
# | policy_loss             | -1.3269765  |
# | qf1_loss                | 0.11634705  |
# | qf2_loss                | 0.061007086 |
# | success rate            | 1           |
# | time_elapsed            | 1           |
# | total timesteps         | 100         |
# | value_loss              | 0.74661946  |
# -----------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.9703197    |
# | ent_coef_loss           | -0.10103407  |
# | entropy                 | 2.5697665    |
# | episodes                | 200          |
# | fps                     | 68           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 101          |
# | policy_loss             | -0.85467696  |
# | qf1_loss                | 0.0050983476 |
# | qf2_loss                | 0.0039814464 |
# | success rate            | 1            |
# | time_elapsed            | 2            |
# | total timesteps         | 200          |
# | value_loss              | 0.015244074  |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.9415148    |
# | ent_coef_loss           | -0.2002518   |
# | entropy                 | 2.574163     |
# | episodes                | 300          |
# | fps                     | 67           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 201          |
# | policy_loss             | -0.7633836   |
# | qf1_loss                | 0.0035208883 |
# | qf2_loss                | 0.0029444662 |
# | success rate            | 1            |
# | time_elapsed            | 4            |
# | total timesteps         | 300          |
# | value_loss              | 0.013032668  |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.9136065    |
# | ent_coef_loss           | -0.3052894   |
# | entropy                 | 2.5270643    |
# | episodes                | 400          |
# | fps                     | 67           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 301          |
# | policy_loss             | -0.7896446   |
# | qf1_loss                | 0.00407737   |
# | qf2_loss                | 0.0034763948 |
# | success rate            | 1            |
# | time_elapsed            | 5            |
# | total timesteps         | 400          |
# | value_loss              | 0.0117604155 |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.88654613   |
# | ent_coef_loss           | -0.40574443  |
# | entropy                 | 2.5392478    |
# | episodes                | 500          |
# | fps                     | 67           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 401          |
# | policy_loss             | -0.7354736   |
# | qf1_loss                | 0.0033194502 |
# | qf2_loss                | 0.0027460633 |
# | success rate            | 1            |
# | time_elapsed            | 7            |
# | total timesteps         | 500          |
# | value_loss              | 0.006662366  |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.86032325   |
# | ent_coef_loss           | -0.5092074   |
# | entropy                 | 2.5597463    |
# | episodes                | 600          |
# | fps                     | 67           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 501          |
# | policy_loss             | -0.707245    |
# | qf1_loss                | 0.0033482425 |
# | qf2_loss                | 0.0031040625 |
# | success rate            | 1            |
# | time_elapsed            | 8            |
# | total timesteps         | 600          |
# | value_loss              | 0.0067769215 |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.8348706    |
# | ent_coef_loss           | -0.61300546  |
# | entropy                 | 2.5697756    |
# | episodes                | 700          |
# | fps                     | 67           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 601          |
# | policy_loss             | -0.6900954   |
# | qf1_loss                | 0.0033722222 |
# | qf2_loss                | 0.0035287286 |
# | success rate            | 1            |
# | time_elapsed            | 10           |
# | total timesteps         | 700          |
# | value_loss              | 0.02513661   |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.8101717    |
# | ent_coef_loss           | -0.70934844  |
# | entropy                 | 2.5608935    |
# | episodes                | 800          |
# | fps                     | 67           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 701          |
# | policy_loss             | -0.6362045   |
# | qf1_loss                | 0.0032853591 |
# | qf2_loss                | 0.003228786  |
# | success rate            | 1            |
# | time_elapsed            | 11           |
# | total timesteps         | 800          |
# | value_loss              | 0.011571585  |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.786217     |
# | ent_coef_loss           | -0.8126657   |
# | entropy                 | 2.5398378    |
# | episodes                | 900          |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 801          |
# | policy_loss             | -0.618453    |
# | qf1_loss                | 0.0028275384 |
# | qf2_loss                | 0.0028095625 |
# | success rate            | 1            |
# | time_elapsed            | 13           |
# | total timesteps         | 900          |
# | value_loss              | 0.014564138  |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.7629624    |
# | ent_coef_loss           | -0.91382986  |
# | entropy                 | 2.5971432    |
# | episodes                | 1000         |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 901          |
# | policy_loss             | -0.58218     |
# | qf1_loss                | 0.0030043302 |
# | qf2_loss                | 0.0022110639 |
# | success rate            | 1            |
# | time_elapsed            | 14           |
# | total timesteps         | 1000         |
# | value_loss              | 0.008050863  |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.74037504   |
# | ent_coef_loss           | -1.0073602   |
# | entropy                 | 2.602073     |
# | episodes                | 1100         |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 1001         |
# | policy_loss             | -0.5374303   |
# | qf1_loss                | 0.002661014  |
# | qf2_loss                | 0.0018424469 |
# | success rate            | 1            |
# | time_elapsed            | 16           |
# | total timesteps         | 1100         |
# | value_loss              | 0.009610946  |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.7185172    |
# | ent_coef_loss           | -1.110457    |
# | entropy                 | 2.5620866    |
# | episodes                | 1200         |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 1101         |
# | policy_loss             | -0.49365994  |
# | qf1_loss                | 0.0027423298 |
# | qf2_loss                | 0.0012168781 |
# | success rate            | 1            |
# | time_elapsed            | 17           |
# | total timesteps         | 1200         |
# | value_loss              | 0.0059821066 |
# ------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.69727606   |
# | ent_coef_loss           | -1.2192323   |
# | entropy                 | 2.5800061    |
# | episodes                | 1300         |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 1201         |
# | policy_loss             | -0.48666865  |
# | qf1_loss                | 0.0013412186 |
# | qf2_loss                | 0.0004102926 |
# | success rate            | 1            |
# | time_elapsed            | 19           |
# | total timesteps         | 1300         |
# | value_loss              | 0.010157927  |
# ------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.6766711     |
# | ent_coef_loss           | -1.3135191    |
# | entropy                 | 2.5851114     |
# | episodes                | 1400          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 1301          |
# | policy_loss             | -0.46816272   |
# | qf1_loss                | 0.0015120797  |
# | qf2_loss                | 0.00037160498 |
# | success rate            | 1             |
# | time_elapsed            | 20            |
# | total timesteps         | 1400          |
# | value_loss              | 0.0063495394  |
# -------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.6566409    |
# | ent_coef_loss           | -1.4140787   |
# | entropy                 | 2.573803     |
# | episodes                | 1500         |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 1401         |
# | policy_loss             | -0.42240596  |
# | qf1_loss                | 0.0011927157 |
# | qf2_loss                | 0.0002965954 |
# | success rate            | 1            |
# | time_elapsed            | 22           |
# | total timesteps         | 1500         |
# | value_loss              | 0.007865505  |
# ------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.6372315     |
# | ent_coef_loss           | -1.5130186    |
# | entropy                 | 2.5613732     |
# | episodes                | 1600          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 1501          |
# | policy_loss             | -0.39229336   |
# | qf1_loss                | 0.0009010671  |
# | qf2_loss                | 0.00021899557 |
# | success rate            | 1             |
# | time_elapsed            | 23            |
# | total timesteps         | 1600          |
# | value_loss              | 0.008315985   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.61839265    |
# | ent_coef_loss           | -1.6273779    |
# | entropy                 | 2.5623984     |
# | episodes                | 1700          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 1601          |
# | policy_loss             | -0.39617926   |
# | qf1_loss                | 0.00061265565 |
# | qf2_loss                | 0.00020544403 |
# | success rate            | 1             |
# | time_elapsed            | 25            |
# | total timesteps         | 1700          |
# | value_loss              | 0.00932615    |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.6000843     |
# | ent_coef_loss           | -1.7230179    |
# | entropy                 | 2.5780592     |
# | episodes                | 1800          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 1701          |
# | policy_loss             | -0.3640004    |
# | qf1_loss                | 0.0006883311  |
# | qf2_loss                | 0.00022538878 |
# | success rate            | 1             |
# | time_elapsed            | 27            |
# | total timesteps         | 1800          |
# | value_loss              | 0.008267914   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.5823409     |
# | ent_coef_loss           | -1.8193145    |
# | entropy                 | 2.5687935     |
# | episodes                | 1900          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 1801          |
# | policy_loss             | -0.33440006   |
# | qf1_loss                | 0.00024594896 |
# | qf2_loss                | 0.00017398805 |
# | success rate            | 1             |
# | time_elapsed            | 28            |
# | total timesteps         | 1900          |
# | value_loss              | 0.005148791   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.5651344     |
# | ent_coef_loss           | -1.9248816    |
# | entropy                 | 2.5854387     |
# | episodes                | 2000          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 1901          |
# | policy_loss             | -0.3315018    |
# | qf1_loss                | 0.0003379793  |
# | qf2_loss                | 0.00015330123 |
# | success rate            | 1             |
# | time_elapsed            | 30            |
# | total timesteps         | 2000          |
# | value_loss              | 0.0057677077  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.5484326     |
# | ent_coef_loss           | -2.0130987    |
# | entropy                 | 2.580648      |
# | episodes                | 2100          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2001          |
# | policy_loss             | -0.25503868   |
# | qf1_loss                | 0.00021397816 |
# | qf2_loss                | 0.00013223595 |
# | success rate            | 1             |
# | time_elapsed            | 31            |
# | total timesteps         | 2100          |
# | value_loss              | 0.0036821489  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.53222156    |
# | ent_coef_loss           | -2.1228595    |
# | entropy                 | 2.5791364     |
# | episodes                | 2200          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2101          |
# | policy_loss             | -0.24191731   |
# | qf1_loss                | 0.00020370258 |
# | qf2_loss                | 0.00018886339 |
# | success rate            | 1             |
# | time_elapsed            | 33            |
# | total timesteps         | 2200          |
# | value_loss              | 0.0025928235  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.5164913     |
# | ent_coef_loss           | -2.2002404    |
# | entropy                 | 2.5516045     |
# | episodes                | 2300          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2201          |
# | policy_loss             | -0.20265901   |
# | qf1_loss                | 0.00018740672 |
# | qf2_loss                | 0.00015119986 |
# | success rate            | 1             |
# | time_elapsed            | 34            |
# | total timesteps         | 2300          |
# | value_loss              | 0.0027366178  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.50122076    |
# | ent_coef_loss           | -2.3320532    |
# | entropy                 | 2.5831013     |
# | episodes                | 2400          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2301          |
# | policy_loss             | -0.2196055    |
# | qf1_loss                | 0.00018120094 |
# | qf2_loss                | 7.517934e-05  |
# | success rate            | 1             |
# | time_elapsed            | 36            |
# | total timesteps         | 2400          |
# | value_loss              | 0.003507447   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.48639917    |
# | ent_coef_loss           | -2.4437861    |
# | entropy                 | 2.5561767     |
# | episodes                | 2500          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2401          |
# | policy_loss             | -0.20060699   |
# | qf1_loss                | 0.0002043565  |
# | qf2_loss                | 0.00012810482 |
# | success rate            | 1             |
# | time_elapsed            | 37            |
# | total timesteps         | 2500          |
# | value_loss              | 0.003981569   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.47201967    |
# | ent_coef_loss           | -2.5379007    |
# | entropy                 | 2.5807304     |
# | episodes                | 2600          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2501          |
# | policy_loss             | -0.19895655   |
# | qf1_loss                | 0.00017856594 |
# | qf2_loss                | 0.00010788946 |
# | success rate            | 1             |
# | time_elapsed            | 39            |
# | total timesteps         | 2600          |
# | value_loss              | 0.0021464087  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.4580535     |
# | ent_coef_loss           | -2.6263008    |
# | entropy                 | 2.5912356     |
# | episodes                | 2700          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2601          |
# | policy_loss             | -0.16087317   |
# | qf1_loss                | 0.00015260925 |
# | qf2_loss                | 0.00010824006 |
# | success rate            | 1             |
# | time_elapsed            | 40            |
# | total timesteps         | 2700          |
# | value_loss              | 0.002318351   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.44452694    |
# | ent_coef_loss           | -2.7543144    |
# | entropy                 | 2.5582201     |
# | episodes                | 2800          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2701          |
# | policy_loss             | -0.17373517   |
# | qf1_loss                | 0.00018459352 |
# | qf2_loss                | 0.00011429964 |
# | success rate            | 1             |
# | time_elapsed            | 42            |
# | total timesteps         | 2800          |
# | value_loss              | 0.0036986098  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.4313839     |
# | ent_coef_loss           | -2.853695     |
# | entropy                 | 2.5845103     |
# | episodes                | 2900          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2801          |
# | policy_loss             | -0.1463468    |
# | qf1_loss                | 0.00014466126 |
# | qf2_loss                | 8.841756e-05  |
# | success rate            | 1             |
# | time_elapsed            | 43            |
# | total timesteps         | 2900          |
# | value_loss              | 0.004324169   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.4186346     |
# | ent_coef_loss           | -2.9313202    |
# | entropy                 | 2.564506      |
# | episodes                | 3000          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 2901          |
# | policy_loss             | -0.097485825  |
# | qf1_loss                | 0.00013616757 |
# | qf2_loss                | 9.962593e-05  |
# | success rate            | 1             |
# | time_elapsed            | 45            |
# | total timesteps         | 3000          |
# | value_loss              | 0.0015439623  |
# -------------------------------------------
# --------------------------------------------
# | current_lr              | 0.0003         |
# | ent_coef                | 0.40625712     |
# | ent_coef_loss           | -3.0369363     |
# | entropy                 | 2.58568        |
# | episodes                | 3100           |
# | fps                     | 66             |
# | mean 100 episode reward | -0.5           |
# | n_updates               | 3001           |
# | policy_loss             | -0.103039965   |
# | qf1_loss                | 0.000116005984 |
# | qf2_loss                | 8.888509e-05   |
# | success rate            | 1              |
# | time_elapsed            | 46             |
# | total timesteps         | 3100           |
# | value_loss              | 0.0021647154   |
# --------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.3942501     |
# | ent_coef_loss           | -3.1559653    |
# | entropy                 | 2.58427       |
# | episodes                | 3200          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 3101          |
# | policy_loss             | -0.074365675  |
# | qf1_loss                | 0.00011716467 |
# | qf2_loss                | 0.00013190148 |
# | success rate            | 1             |
# | time_elapsed            | 47            |
# | total timesteps         | 3200          |
# | value_loss              | 0.0016335339  |
# -------------------------------------------
# --------------------------------------------
# | current_lr              | 0.0003         |
# | ent_coef                | 0.38260445     |
# | ent_coef_loss           | -3.2454858     |
# | entropy                 | 2.588288       |
# | episodes                | 3300           |
# | fps                     | 66             |
# | mean 100 episode reward | -0.5           |
# | n_updates               | 3201           |
# | policy_loss             | -0.06964481    |
# | qf1_loss                | 0.00014951883  |
# | qf2_loss                | 0.000101384205 |
# | success rate            | 1              |
# | time_elapsed            | 49             |
# | total timesteps         | 3300           |
# | value_loss              | 0.0015621207   |
# --------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.37129283    |
# | ent_coef_loss           | -3.3454409    |
# | entropy                 | 2.5898142     |
# | episodes                | 3400          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.4          |
# | n_updates               | 3301          |
# | policy_loss             | -0.037794188  |
# | qf1_loss                | 0.00011292506 |
# | qf2_loss                | 0.00010266904 |
# | success rate            | 1             |
# | time_elapsed            | 50            |
# | total timesteps         | 3400          |
# | value_loss              | 0.0010550315  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.36031651    |
# | ent_coef_loss           | -3.4608097    |
# | entropy                 | 2.5540438     |
# | episodes                | 3500          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.4          |
# | n_updates               | 3401          |
# | policy_loss             | -0.03856542   |
# | qf1_loss                | 8.854778e-05  |
# | qf2_loss                | 5.7480862e-05 |
# | success rate            | 1             |
# | time_elapsed            | 52            |
# | total timesteps         | 3500          |
# | value_loss              | 0.0049341363  |
# -------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.34967414   |
# | ent_coef_loss           | -3.5207076   |
# | entropy                 | 2.5460339    |
# | episodes                | 3600         |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 3501         |
# | policy_loss             | -0.011760134 |
# | qf1_loss                | 8.879389e-05 |
# | qf2_loss                | 6.500246e-05 |
# | success rate            | 1            |
# | time_elapsed            | 53           |
# | total timesteps         | 3600         |
# | value_loss              | 0.0011270803 |
# ------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.33933333    |
# | ent_coef_loss           | -3.6529226    |
# | entropy                 | 2.5743535     |
# | episodes                | 3700          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.4          |
# | n_updates               | 3601          |
# | policy_loss             | 0.011678882   |
# | qf1_loss                | 0.00010078671 |
# | qf2_loss                | 7.72828e-05   |
# | success rate            | 1             |
# | time_elapsed            | 55            |
# | total timesteps         | 3700          |
# | value_loss              | 0.0015491034  |
# -------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.3292938    |
# | ent_coef_loss           | -3.7688181   |
# | entropy                 | 2.5616636    |
# | episodes                | 3800         |
# | fps                     | 66           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 3701         |
# | policy_loss             | 0.0029283725 |
# | qf1_loss                | 7.924994e-05 |
# | qf2_loss                | 7.601881e-05 |
# | success rate            | 1            |
# | time_elapsed            | 56           |
# | total timesteps         | 3800         |
# | value_loss              | 0.0068329284 |
# ------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.3195649     |
# | ent_coef_loss           | -3.8182383    |
# | entropy                 | 2.5568705     |
# | episodes                | 3900          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 3801          |
# | policy_loss             | 0.058767088   |
# | qf1_loss                | 9.0705944e-05 |
# | qf2_loss                | 4.5718247e-05 |
# | success rate            | 1             |
# | time_elapsed            | 58            |
# | total timesteps         | 3900          |
# | value_loss              | 0.00088259444 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.3101229     |
# | ent_coef_loss           | -3.9297142    |
# | entropy                 | 2.5719945     |
# | episodes                | 4000          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 3901          |
# | policy_loss             | 0.06597685    |
# | qf1_loss                | 6.8429916e-05 |
# | qf2_loss                | 6.2708736e-05 |
# | success rate            | 1             |
# | time_elapsed            | 59            |
# | total timesteps         | 4000          |
# | value_loss              | 0.0008812286  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.30095264    |
# | ent_coef_loss           | -4.0114846    |
# | entropy                 | 2.5681813     |
# | episodes                | 4100          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4001          |
# | policy_loss             | 0.059204705   |
# | qf1_loss                | 9.915454e-05  |
# | qf2_loss                | 4.836879e-05  |
# | success rate            | 1             |
# | time_elapsed            | 61            |
# | total timesteps         | 4100          |
# | value_loss              | 0.00085935905 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.29205877    |
# | ent_coef_loss           | -4.162738     |
# | entropy                 | 2.56316       |
# | episodes                | 4200          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4101          |
# | policy_loss             | 0.066937566   |
# | qf1_loss                | 7.190461e-05  |
# | qf2_loss                | 5.3999764e-05 |
# | success rate            | 1             |
# | time_elapsed            | 62            |
# | total timesteps         | 4200          |
# | value_loss              | 0.00079051545 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.2834245     |
# | ent_coef_loss           | -4.2435875    |
# | entropy                 | 2.5915992     |
# | episodes                | 4300          |
# | fps                     | 66            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4201          |
# | policy_loss             | 0.09865324    |
# | qf1_loss                | 6.01094e-05   |
# | qf2_loss                | 3.8171813e-05 |
# | success rate            | 1             |
# | time_elapsed            | 64            |
# | total timesteps         | 4300          |
# | value_loss              | 0.0009105551  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.27505022    |
# | ent_coef_loss           | -4.3408375    |
# | entropy                 | 2.5687246     |
# | episodes                | 4400          |
# | fps                     | 65            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4301          |
# | policy_loss             | 0.078938015   |
# | qf1_loss                | 5.8615744e-05 |
# | qf2_loss                | 5.994707e-05  |
# | success rate            | 1             |
# | time_elapsed            | 66            |
# | total timesteps         | 4400          |
# | value_loss              | 0.0008496683  |
# -------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.26691577   |
# | ent_coef_loss           | -4.44215     |
# | entropy                 | 2.5446491    |
# | episodes                | 4500         |
# | fps                     | 65           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 4401         |
# | policy_loss             | 0.09283175   |
# | qf1_loss                | 5.585598e-05 |
# | qf2_loss                | 6.682443e-05 |
# | success rate            | 1            |
# | time_elapsed            | 68           |
# | total timesteps         | 4500         |
# | value_loss              | 0.0005885834 |
# ------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.2590288     |
# | ent_coef_loss           | -4.5174522    |
# | entropy                 | 2.5670018     |
# | episodes                | 4600          |
# | fps                     | 65            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4501          |
# | policy_loss             | 0.11395547    |
# | qf1_loss                | 9.244347e-05  |
# | qf2_loss                | 5.429108e-05  |
# | success rate            | 1             |
# | time_elapsed            | 70            |
# | total timesteps         | 4600          |
# | value_loss              | 0.00075887324 |
# -------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.25136948   |
# | ent_coef_loss           | -4.630338    |
# | entropy                 | 2.5770783    |
# | episodes                | 4700         |
# | fps                     | 65           |
# | mean 100 episode reward | -0.5         |
# | n_updates               | 4601         |
# | policy_loss             | 0.12030859   |
# | qf1_loss                | 5.887291e-05 |
# | qf2_loss                | 5.688355e-05 |
# | success rate            | 1            |
# | time_elapsed            | 72           |
# | total timesteps         | 4700         |
# | value_loss              | 0.0009082528 |
# ------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.24394235    |
# | ent_coef_loss           | -4.745345     |
# | entropy                 | 2.5569968     |
# | episodes                | 4800          |
# | fps                     | 65            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4701          |
# | policy_loss             | 0.13088882    |
# | qf1_loss                | 6.9067886e-05 |
# | qf2_loss                | 4.621785e-05  |
# | success rate            | 1             |
# | time_elapsed            | 73            |
# | total timesteps         | 4800          |
# | value_loss              | 0.0006625076  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.23673244    |
# | ent_coef_loss           | -4.832096     |
# | entropy                 | 2.559347      |
# | episodes                | 4900          |
# | fps                     | 65            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4801          |
# | policy_loss             | 0.14562516    |
# | qf1_loss                | 6.0507737e-05 |
# | qf2_loss                | 4.1036572e-05 |
# | success rate            | 1             |
# | time_elapsed            | 75            |
# | total timesteps         | 4900          |
# | value_loss              | 0.0010889843  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.22973649    |
# | ent_coef_loss           | -4.932183     |
# | entropy                 | 2.5806437     |
# | episodes                | 5000          |
# | fps                     | 65            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 4901          |
# | policy_loss             | 0.15973017    |
# | qf1_loss                | 5.6840985e-05 |
# | qf2_loss                | 4.3674445e-05 |
# | success rate            | 1             |
# | time_elapsed            | 76            |
# | total timesteps         | 5000          |
# | value_loss              | 0.0006181529  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.22295111    |
# | ent_coef_loss           | -5.000823     |
# | entropy                 | 2.5744727     |
# | episodes                | 5100          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5001          |
# | policy_loss             | 0.18851766    |
# | qf1_loss                | 4.941667e-05  |
# | qf2_loss                | 4.2435033e-05 |
# | success rate            | 1             |
# | time_elapsed            | 78            |
# | total timesteps         | 5100          |
# | value_loss              | 0.00064181455 |
# -------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.21635926   |
# | ent_coef_loss           | -5.2086673   |
# | entropy                 | 2.5611346    |
# | episodes                | 5200         |
# | fps                     | 64           |
# | mean 100 episode reward | -0.4         |
# | n_updates               | 5101         |
# | policy_loss             | 0.18127921   |
# | qf1_loss                | 5.506192e-05 |
# | qf2_loss                | 3.69088e-05  |
# | success rate            | 1            |
# | time_elapsed            | 80           |
# | total timesteps         | 5200         |
# | value_loss              | 0.0020204724 |
# ------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.20996451    |
# | ent_coef_loss           | -5.2710724    |
# | entropy                 | 2.5477757     |
# | episodes                | 5300          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5201          |
# | policy_loss             | 0.17151457    |
# | qf1_loss                | 6.19792e-05   |
# | qf2_loss                | 4.733689e-05  |
# | success rate            | 1             |
# | time_elapsed            | 81            |
# | total timesteps         | 5300          |
# | value_loss              | 0.00041071227 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.2037583     |
# | ent_coef_loss           | -5.368264     |
# | entropy                 | 2.574667      |
# | episodes                | 5400          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5301          |
# | policy_loss             | 0.18482848    |
# | qf1_loss                | 4.951243e-05  |
# | qf2_loss                | 4.4448825e-05 |
# | success rate            | 1             |
# | time_elapsed            | 83            |
# | total timesteps         | 5400          |
# | value_loss              | 0.000688998   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.1977325     |
# | ent_coef_loss           | -5.5905495    |
# | entropy                 | 2.5869315     |
# | episodes                | 5500          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5401          |
# | policy_loss             | 0.1798414     |
# | qf1_loss                | 4.2679072e-05 |
# | qf2_loss                | 5.6027176e-05 |
# | success rate            | 1             |
# | time_elapsed            | 84            |
# | total timesteps         | 5500          |
# | value_loss              | 0.005061508   |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.19188844    |
# | ent_coef_loss           | -5.5233374    |
# | entropy                 | 2.5974736     |
# | episodes                | 5600          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5501          |
# | policy_loss             | 0.19142519    |
# | qf1_loss                | 6.2404004e-05 |
# | qf2_loss                | 4.6022076e-05 |
# | success rate            | 1             |
# | time_elapsed            | 86            |
# | total timesteps         | 5600          |
# | value_loss              | 0.00046893756 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.18622135    |
# | ent_coef_loss           | -5.635165     |
# | entropy                 | 2.5854967     |
# | episodes                | 5700          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5601          |
# | policy_loss             | 0.19133674    |
# | qf1_loss                | 7.0193564e-05 |
# | qf2_loss                | 4.9253387e-05 |
# | success rate            | 1             |
# | time_elapsed            | 87            |
# | total timesteps         | 5700          |
# | value_loss              | 0.0005446068  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.18072096    |
# | ent_coef_loss           | -5.7173715    |
# | entropy                 | 2.5699272     |
# | episodes                | 5800          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5701          |
# | policy_loss             | 0.23124672    |
# | qf1_loss                | 4.6407135e-05 |
# | qf2_loss                | 5.1544128e-05 |
# | success rate            | 1             |
# | time_elapsed            | 89            |
# | total timesteps         | 5800          |
# | value_loss              | 0.0007707999  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.17538378    |
# | ent_coef_loss           | -5.846649     |
# | entropy                 | 2.569053      |
# | episodes                | 5900          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5801          |
# | policy_loss             | 0.2207964     |
# | qf1_loss                | 5.65371e-05   |
# | qf2_loss                | 5.2427815e-05 |
# | success rate            | 1             |
# | time_elapsed            | 90            |
# | total timesteps         | 5900          |
# | value_loss              | 0.0004414155  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.17019972    |
# | ent_coef_loss           | -5.971594     |
# | entropy                 | 2.5785651     |
# | episodes                | 6000          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 5901          |
# | policy_loss             | 0.23789003    |
# | qf1_loss                | 3.4878205e-05 |
# | qf2_loss                | 3.17468e-05   |
# | success rate            | 1             |
# | time_elapsed            | 92            |
# | total timesteps         | 6000          |
# | value_loss              | 0.00030024195 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.16517207    |
# | ent_coef_loss           | -6.10383      |
# | entropy                 | 2.5518417     |
# | episodes                | 6100          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 6001          |
# | policy_loss             | 0.2173782     |
# | qf1_loss                | 3.9538892e-05 |
# | qf2_loss                | 3.5124303e-05 |
# | success rate            | 1             |
# | time_elapsed            | 93            |
# | total timesteps         | 6100          |
# | value_loss              | 0.00024696518 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.1602898     |
# | ent_coef_loss           | -6.083665     |
# | entropy                 | 2.5586562     |
# | episodes                | 6200          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 6101          |
# | policy_loss             | 0.25100553    |
# | qf1_loss                | 4.6884892e-05 |
# | qf2_loss                | 4.2155938e-05 |
# | success rate            | 1             |
# | time_elapsed            | 95            |
# | total timesteps         | 6200          |
# | value_loss              | 0.00029424985 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.1555585     |
# | ent_coef_loss           | -6.253314     |
# | entropy                 | 2.5531194     |
# | episodes                | 6300          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 6201          |
# | policy_loss             | 0.23310232    |
# | qf1_loss                | 3.768521e-05  |
# | qf2_loss                | 4.7024947e-05 |
# | success rate            | 1             |
# | time_elapsed            | 97            |
# | total timesteps         | 6300          |
# | value_loss              | 0.00022478962 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.15095647    |
# | ent_coef_loss           | -6.341136     |
# | entropy                 | 2.5573611     |
# | episodes                | 6400          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 6301          |
# | policy_loss             | 0.26725417    |
# | qf1_loss                | 2.2322227e-05 |
# | qf2_loss                | 2.4613943e-05 |
# | success rate            | 1             |
# | time_elapsed            | 98            |
# | total timesteps         | 6400          |
# | value_loss              | 0.00025372906 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.14649773    |
# | ent_coef_loss           | -6.4413185    |
# | entropy                 | 2.566112      |
# | episodes                | 6500          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 6401          |
# ...
# | success rate            | 1             |
# | time_elapsed            | 123           |
# | total timesteps         | 7900          |
# | value_loss              | 0.00014964692 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.093405366   |
# | ent_coef_loss           | -7.9591093    |
# | entropy                 | 2.5685668     |
# | episodes                | 8000          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 7901          |
# | policy_loss             | 0.3451834     |
# | qf1_loss                | 1.8380131e-05 |
# | qf2_loss                | 1.4158253e-05 |
# | success rate            | 1             |
# | time_elapsed            | 124           |
# | total timesteps         | 8000          |
# | value_loss              | 0.00012505862 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.09064591    |
# | ent_coef_loss           | -8.164745     |
# | entropy                 | 2.564538      |
# | episodes                | 8100          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 8001          |
# | policy_loss             | 0.34435648    |
# | qf1_loss                | 1.9900557e-05 |
# | qf2_loss                | 1.6100543e-05 |
# | success rate            | 1             |
# | time_elapsed            | 126           |
# | total timesteps         | 8100          |
# | value_loss              | 0.0004446509  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.08796738    |
# | ent_coef_loss           | -8.180458     |
# | entropy                 | 2.563809      |
# | episodes                | 8200          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 8101          |
# | policy_loss             | 0.34431145    |
# | qf1_loss                | 1.6438526e-05 |
# | qf2_loss                | 7.865602e-06  |
# | success rate            | 1             |
# | time_elapsed            | 127           |
# | total timesteps         | 8200          |
# | value_loss              | 9.726529e-05  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.08536678    |
# | ent_coef_loss           | -8.310102     |
# | entropy                 | 2.5616417     |
# | episodes                | 8300          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 8201          |
# | policy_loss             | 0.36816645    |
# | qf1_loss                | 1.7856175e-05 |
# | qf2_loss                | 1.1210954e-05 |
# | success rate            | 1             |
# | time_elapsed            | 129           |
# | total timesteps         | 8300          |
# | value_loss              | 0.0001361244  |
# -------------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.082844816  |
# | ent_coef_loss           | -8.357851    |
# | entropy                 | 2.5817554    |
# | episodes                | 8400         |
# | fps                     | 64           |
# | mean 100 episode reward | -0.4         |
# | n_updates               | 8301         |
# | policy_loss             | 0.3551737    |
# | qf1_loss                | 1.761818e-05 |
# | qf2_loss                | 9.933503e-06 |
# | success rate            | 1            |
# | time_elapsed            | 130          |
# | total timesteps         | 8400         |
# | value_loss              | 9.533159e-05 |
# ------------------------------------------
# --------------------------------------------
# | current_lr              | 0.0003         |
# | ent_coef                | 0.080395505    |
# | ent_coef_loss           | -8.496559      |
# | entropy                 | 2.5947533      |
# | episodes                | 8500           |
# | fps                     | 64             |
# | mean 100 episode reward | -0.5           |
# | n_updates               | 8401           |
# | policy_loss             | 0.38248396     |
# | qf1_loss                | 1.3711002e-05  |
# | qf2_loss                | 1.0847427e-05  |
# | success rate            | 1              |
# | time_elapsed            | 132            |
# | total timesteps         | 8500           |
# | value_loss              | 0.000117681426 |
# --------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.07802063    |
# | ent_coef_loss           | -8.590189     |
# | entropy                 | 2.5632463     |
# | episodes                | 8600          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 8501          |
# | policy_loss             | 0.36282656    |
# | qf1_loss                | 1.8561337e-05 |
# | qf2_loss                | 1.0784877e-05 |
# | success rate            | 1             |
# | time_elapsed            | 133           |
# | total timesteps         | 8600          |
# | value_loss              | 7.591068e-05  |
# -------------------------------------------
# --------------------------------------------
# | current_lr              | 0.0003         |
# | ent_coef                | 0.075713985    |
# | ent_coef_loss           | -8.681646      |
# | entropy                 | 2.5842786      |
# | episodes                | 8700           |
# | fps                     | 64             |
# | mean 100 episode reward | -0.5           |
# | n_updates               | 8601           |
# | policy_loss             | 0.3710413      |
# | qf1_loss                | 1.1267201e-05  |
# | qf2_loss                | 1.8486502e-05  |
# | success rate            | 1              |
# | time_elapsed            | 135            |
# | total timesteps         | 8700           |
# | value_loss              | 0.000120387296 |
# --------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.073477894   |
# | ent_coef_loss           | -8.907973     |
# | entropy                 | 2.5539665     |
# | episodes                | 8800          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 8701          |
# | policy_loss             | 0.38899148    |
# | qf1_loss                | 1.3160299e-05 |
# | qf2_loss                | 1.8130344e-05 |
# | success rate            | 1             |
# | time_elapsed            | 137           |
# | total timesteps         | 8800          |
# | value_loss              | 0.00014450254 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.07130701    |
# | ent_coef_loss           | -8.891691     |
# | entropy                 | 2.5604773     |
# | episodes                | 8900          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 8801          |
# | policy_loss             | 0.38704735    |
# | qf1_loss                | 1.7011682e-05 |
# | qf2_loss                | 1.1666765e-05 |
# | success rate            | 1             |
# | time_elapsed            | 138           |
# | total timesteps         | 8900          |
# | value_loss              | 0.00015851215 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.069201514   |
# | ent_coef_loss           | -8.96773      |
# | entropy                 | 2.5789008     |
# | episodes                | 9000          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 8901          |
# | policy_loss             | 0.36252388    |
# | qf1_loss                | 1.1945418e-05 |
# | qf2_loss                | 1.6017966e-05 |
# | success rate            | 1             |
# | time_elapsed            | 140           |
# | total timesteps         | 9000          |
# | value_loss              | 7.886649e-05  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.06715447    |
# | ent_coef_loss           | -9.075875     |
# | entropy                 | 2.5946102     |
# | episodes                | 9100          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9001          |
# | policy_loss             | 0.3878112     |
# | qf1_loss                | 1.3626741e-05 |
# | qf2_loss                | 1.623981e-05  |
# | success rate            | 1             |
# | time_elapsed            | 141           |
# | total timesteps         | 9100          |
# | value_loss              | 9.0797796e-05 |
# -------------------------------------------
# --------------------------------------------
# | current_lr              | 0.0003         |
# | ent_coef                | 0.06517076     |
# | ent_coef_loss           | -9.251135      |
# | entropy                 | 2.5615337      |
# | episodes                | 9200           |
# | fps                     | 64             |
# | mean 100 episode reward | -0.5           |
# | n_updates               | 9101           |
# | policy_loss             | 0.37454942     |
# | qf1_loss                | 1.1707338e-05  |
# | qf2_loss                | 1.35333175e-05 |
# | success rate            | 1              |
# | time_elapsed            | 143            |
# | total timesteps         | 9200           |
# | value_loss              | 5.754872e-05   |
# --------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.063245006   |
# | ent_coef_loss           | -9.36676      |
# | entropy                 | 2.550411      |
# | episodes                | 9300          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9201          |
# | policy_loss             | 0.3745096     |
# | qf1_loss                | 1.2077346e-05 |
# | qf2_loss                | 1.5030846e-05 |
# | success rate            | 1             |
# | time_elapsed            | 145           |
# | total timesteps         | 9300          |
# | value_loss              | 7.6271e-05    |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.061375134   |
# | ent_coef_loss           | -9.3702545    |
# | entropy                 | 2.5467358     |
# | episodes                | 9400          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9301          |
# | policy_loss             | 0.37275928    |
# | qf1_loss                | 1.6033904e-05 |
# | qf2_loss                | 1.0275824e-05 |
# | success rate            | 1             |
# | time_elapsed            | 146           |
# | total timesteps         | 9400          |
# | value_loss              | 8.091931e-05  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.05956151    |
# | ent_coef_loss           | -9.505491     |
# | entropy                 | 2.5577142     |
# | episodes                | 9500          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9401          |
# | policy_loss             | 0.39612195    |
# | qf1_loss                | 8.044917e-06  |
# | qf2_loss                | 9.563366e-06  |
# | success rate            | 1             |
# | time_elapsed            | 147           |
# | total timesteps         | 9500          |
# | value_loss              | 6.1565166e-05 |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.057801977   |
# | ent_coef_loss           | -9.566721     |
# | entropy                 | 2.55689       |
# | episodes                | 9600          |
# | fps                     | 64            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9501          |
# | policy_loss             | 0.39236814    |
# | qf1_loss                | 1.0194082e-05 |
# | qf2_loss                | 9.127598e-06  |
# | success rate            | 1             |
# | time_elapsed            | 149           |
# | total timesteps         | 9600          |
# | value_loss              | 8.261981e-05  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.056094084   |
# | ent_coef_loss           | -9.730677     |
# | entropy                 | 2.55791       |
# | episodes                | 9700          |
# | fps                     | 63            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9601          |
# | policy_loss             | 0.3770851     |
# | qf1_loss                | 1.6328715e-05 |
# | qf2_loss                | 1.1814902e-05 |
# | success rate            | 1             |
# | time_elapsed            | 151           |
# | total timesteps         | 9700          |
# | value_loss              | 5.946122e-05  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.054436192   |
# | ent_coef_loss           | -9.790802     |
# | entropy                 | 2.5430074     |
# | episodes                | 9800          |
# | fps                     | 63            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9701          |
# | policy_loss             | 0.39252764    |
# | qf1_loss                | 1.1357701e-05 |
# | qf2_loss                | 1.0440688e-05 |
# | success rate            | 1             |
# | time_elapsed            | 153           |
# | total timesteps         | 9800          |
# | value_loss              | 6.740344e-05  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.052827436   |
# | ent_coef_loss           | -9.835344     |
# | entropy                 | 2.5570323     |
# | episodes                | 9900          |
# | fps                     | 63            |
# | mean 100 episode reward | -0.4          |
# | n_updates               | 9801          |
# | policy_loss             | 0.37403768    |
# | qf1_loss                | 1.2285889e-05 |
# | qf2_loss                | 1.1207723e-05 |
# | success rate            | 1             |
# | time_elapsed            | 155           |
# | total timesteps         | 9900          |
# | value_loss              | 5.223641e-05  |
# -------------------------------------------
# -------------------------------------------
# | current_lr              | 0.0003        |
# | ent_coef                | 0.051265992   |
# | ent_coef_loss           | -9.978964     |
# | entropy                 | 2.5643702     |
# | episodes                | 10000         |
# | fps                     | 63            |
# | mean 100 episode reward | -0.5          |
# | n_updates               | 9901          |
# | policy_loss             | 0.4113952     |
# | qf1_loss                | 1.406949e-05  |
# | qf2_loss                | 1.0488821e-05 |
# | success rate            | 1             |
# | time_elapsed            | 156           |
# | total timesteps         | 10000         |
# | value_loss              | 5.1191477e-05 |
# -------------------------------------------

# %% [markdown]
# ## Performance of HER model on the parking env
#
# Now, we look at the evaluation of the HER policy on the parking environment

# %%
for i in range(100):
    done = False
    obs = env.reset()
    while not done:
        env.render()
        action, _states = her_parking.predict(obs)
        next_state, reward, done, info = env.step(action)
 
        total_reward.append(reward)
        print(info)
        print(done)
        
        
rewards_average = Average(total_reward) 
  
print("The average of rewards: ",rewards_average)     
env.close()
# Out:
# {'speed': -0.006456494331359863, 'crashed': False, 'action': array([-0.00645649,  0.00726366], dtype=float32), 'is_success': True}
# True
# {'speed': -0.031987905502319336, 'crashed': False, 'action': array([-0.03198791,  0.00257814], dtype=float32), 'is_success': True}
# True
# {'speed': -0.03243362903594971, 'crashed': False, 'action': array([-0.03243363, -0.01940978], dtype=float32), 'is_success': True}
# True
# {'speed': -0.0354120135307312, 'crashed': False, 'action': array([-0.03541201, -0.00528121], dtype=float32), 'is_success': True}
# True
# {'speed': 0.019814491271972656, 'crashed': False, 'action': array([0.01981449, 0.05716217], dtype=float32), 'is_success': True}
# True
# {'speed': 0.019608497619628906, 'crashed': False, 'action': array([0.0196085 , 0.02118444], dtype=float32), 'is_success': True}
# True
# {'speed': 0.014252543449401855, 'crashed': False, 'action': array([0.01425254, 0.0302217 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.0004140138626098633, 'crashed': False, 'action': array([-0.00041401, -0.01079065], dtype=float32), 'is_success': True}
# True
# {'speed': -0.029535353183746338, 'crashed': False, 'action': array([-0.02953535, -0.00351304], dtype=float32), 'is_success': True}
# True
# {'speed': -0.024086952209472656, 'crashed': False, 'action': array([-0.02408695, -0.01839674], dtype=float32), 'is_success': True}
# True
# {'speed': -0.0163382887840271, 'crashed': False, 'action': array([-0.01633829, -0.00199944], dtype=float32), 'is_success': True}
# True
# {'speed': 0.006512165069580078, 'crashed': False, 'action': array([0.00651217, 0.03502858], dtype=float32), 'is_success': True}
# True
# {'speed': -0.03537452220916748, 'crashed': False, 'action': array([-0.03537452, -0.01839435], dtype=float32), 'is_success': True}
# True
# {'speed': -0.00885617733001709, 'crashed': False, 'action': array([-0.00885618, -0.01512021], dtype=float32), 'is_success': True}
# True
# {'speed': 0.020079851150512695, 'crashed': False, 'action': array([0.02007985, 0.03004849], dtype=float32), 'is_success': True}
# True
# {'speed': 0.005739808082580566, 'crashed': False, 'action': array([ 0.00573981, -0.00333303], dtype=float32), 'is_success': True}
# True
# {'speed': -0.019624292850494385, 'crashed': False, 'action': array([-0.01962429, -0.01430541], dtype=float32), 'is_success': True}
# True
# {'speed': 0.01579141616821289, 'crashed': False, 'action': array([0.01579142, 0.03568423], dtype=float32), 'is_success': True}
# True
# {'speed': 0.012192010879516602, 'crashed': False, 'action': array([ 0.01219201, -0.00424957], dtype=float32), 'is_success': True}
# True
# {'speed': 0.010812878608703613, 'crashed': False, 'action': array([0.01081288, 0.03227758], dtype=float32), 'is_success': True}
# True
# {'speed': -0.01470935344696045, 'crashed': False, 'action': array([-0.01470935,  0.00684988], dtype=float32), 'is_success': True}
# True
# {'speed': 0.006163835525512695, 'crashed': False, 'action': array([ 0.00616384, -0.00874305], dtype=float32), 'is_success': True}
# True
# {'speed': -0.005681812763214111, 'crashed': False, 'action': array([-0.00568181,  0.01378298], dtype=float32), 'is_success': True}
# True
# {'speed': 0.019237041473388672, 'crashed': False, 'action': array([0.01923704, 0.01341915], dtype=float32), 'is_success': True}
# True
# {'speed': 0.007272481918334961, 'crashed': False, 'action': array([0.00727248, 0.00671005], dtype=float32), 'is_success': True}
# True
# {'speed': -0.030363619327545166, 'crashed': False, 'action': array([-0.03036362,  0.01633573], dtype=float32), 'is_success': True}
# True
# {'speed': 0.009267807006835938, 'crashed': False, 'action': array([0.00926781, 0.03241694], dtype=float32), 'is_success': True}
# True
# {'speed': -0.021664083003997803, 'crashed': False, 'action': array([-0.02166408, -0.00645441], dtype=float32), 'is_success': True}
# True
# {'speed': -0.020895659923553467, 'crashed': False, 'action': array([-2.089566e-02, -8.583069e-06], dtype=float32), 'is_success': True}
# True
# {'speed': -0.019797861576080322, 'crashed': False, 'action': array([-0.01979786, -0.00061899], dtype=float32), 'is_success': True}
# True
# {'speed': 0.013984203338623047, 'crashed': False, 'action': array([0.0139842 , 0.03694713], dtype=float32), 'is_success': True}
# True
# {'speed': -0.024711012840270996, 'crashed': False, 'action': array([-0.02471101, -0.00209147], dtype=float32), 'is_success': True}
# True
# {'speed': -0.010346531867980957, 'crashed': False, 'action': array([-0.01034653, -0.02498692], dtype=float32), 'is_success': True}
# True
# {'speed': 0.02327895164489746, 'crashed': False, 'action': array([0.02327895, 0.05146885], dtype=float32), 'is_success': True}
# True
# {'speed': -0.028883695602416992, 'crashed': False, 'action': array([-0.0288837 , -0.01353997], dtype=float32), 'is_success': True}
# True
# {'speed': -0.0322871208190918, 'crashed': False, 'action': array([-0.03228712, -0.01838499], dtype=float32), 'is_success': True}
# True
# {'speed': 0.01566290855407715, 'crashed': False, 'action': array([0.01566291, 0.00965083], dtype=float32), 'is_success': True}
# True
# {'speed': -0.0005466341972351074, 'crashed': False, 'action': array([-0.00054663, -0.00680685], dtype=float32), 'is_success': True}
# True
# {'speed': -0.021175861358642578, 'crashed': False, 'action': array([-0.02117586, -0.01878774], dtype=float32), 'is_success': True}
# True
# {'speed': -0.02832895517349243, 'crashed': False, 'action': array([-0.02832896, -0.00695121], dtype=float32), 'is_success': True}
# True
# {'speed': 0.021624088287353516, 'crashed': False, 'action': array([0.02162409, 0.05650783], dtype=float32), 'is_success': True}
# True
# {'speed': -0.023527979850769043, 'crashed': False, 'action': array([-0.02352798, -0.00322288], dtype=float32), 'is_success': True}
# True
# {'speed': 0.011769533157348633, 'crashed': False, 'action': array([0.01176953, 0.03529465], dtype=float32), 'is_success': True}
# True
# {'speed': 0.003516554832458496, 'crashed': False, 'action': array([0.00351655, 0.03696847], dtype=float32), 'is_success': True}
# True
# {'speed': -0.008579552173614502, 'crashed': False, 'action': array([-0.00857955,  0.00365257], dtype=float32), 'is_success': True}
# True
# {'speed': 0.011004209518432617, 'crashed': False, 'action': array([0.01100421, 0.03457212], dtype=float32), 'is_success': True}
# True
# {'speed': -0.0176011323928833, 'crashed': False, 'action': array([-0.01760113, -0.01652724], dtype=float32), 'is_success': True}
# True
# {'speed': 0.009450197219848633, 'crashed': False, 'action': array([0.0094502 , 0.01107335], dtype=float32), 'is_success': True}
# True
# {'speed': 0.0035396814346313477, 'crashed': False, 'action': array([ 0.00353968, -0.00226498], dtype=float32), 'is_success': True}
# True
# {'speed': -0.013510406017303467, 'crashed': False, 'action': array([-0.01351041,  0.00414884], dtype=float32), 'is_success': True}
# True
# {'speed': 0.004407763481140137, 'crashed': False, 'action': array([ 0.00440776, -0.00649422], dtype=float32), 'is_success': True}
# True
# {'speed': 0.017525553703308105, 'crashed': False, 'action': array([0.01752555, 0.03787863], dtype=float32), 'is_success': True}
# True
# {'speed': -0.010388851165771484, 'crashed': False, 'action': array([-0.01038885,  0.0113076 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.03302884101867676, 'crashed': False, 'action': array([-0.03302884, -0.02579767], dtype=float32), 'is_success': True}
# True
# {'speed': 0.012952804565429688, 'crashed': False, 'action': array([ 0.0129528, -0.009803 ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.018318533897399902, 'crashed': False, 'action': array([0.01831853, 0.00033498], dtype=float32), 'is_success': True}
# True
# {'speed': 0.008818507194519043, 'crashed': False, 'action': array([ 0.00881851, -0.00549001], dtype=float32), 'is_success': True}
# True
# {'speed': 0.013158202171325684, 'crashed': False, 'action': array([ 0.0131582 , -0.00627673], dtype=float32), 'is_success': True}
# True
# {'speed': 0.02335488796234131, 'crashed': False, 'action': array([0.02335489, 0.05534792], dtype=float32), 'is_success': True}
# True
# {'speed': 0.013442277908325195, 'crashed': False, 'action': array([0.01344228, 0.04965162], dtype=float32), 'is_success': True}
# True
# {'speed': -0.028051018714904785, 'crashed': False, 'action': array([-0.02805102, -0.00434548], dtype=float32), 'is_success': True}
# True
# {'speed': 0.020557880401611328, 'crashed': False, 'action': array([0.02055788, 0.04678798], dtype=float32), 'is_success': True}
# True
# {'speed': -0.017742574214935303, 'crashed': False, 'action': array([-0.01774257,  0.00174201], dtype=float32), 'is_success': True}
# True
# {'speed': -0.044463396072387695, 'crashed': False, 'action': array([-0.0444634 , -0.01600796], dtype=float32), 'is_success': True}
# True
# {'speed': -0.03427690267562866, 'crashed': False, 'action': array([-0.0342769 , -0.01539314], dtype=float32), 'is_success': True}
# True
# {'speed': 0.010435819625854492, 'crashed': False, 'action': array([0.01043582, 0.00847089], dtype=float32), 'is_success': True}
# True
# {'speed': -0.014842212200164795, 'crashed': False, 'action': array([-0.01484221,  0.01302838], dtype=float32), 'is_success': True}
# True
# {'speed': -0.027298808097839355, 'crashed': False, 'action': array([-0.02729881, -0.02324617], dtype=float32), 'is_success': True}
# True
# {'speed': -0.015053927898406982, 'crashed': False, 'action': array([-0.01505393,  0.00048459], dtype=float32), 'is_success': True}
# True
# {'speed': -0.00446009635925293, 'crashed': False, 'action': array([-0.0044601 , -0.01834464], dtype=float32), 'is_success': True}
# True
# {'speed': -0.013929903507232666, 'crashed': False, 'action': array([-0.0139299 ,  0.00246191], dtype=float32), 'is_success': True}
# True
# {'speed': 0.016976475715637207, 'crashed': False, 'action': array([0.01697648, 0.05334365], dtype=float32), 'is_success': True}
# True
# {'speed': -0.006437778472900391, 'crashed': False, 'action': array([-0.00643778,  0.00572681], dtype=float32), 'is_success': True}
# True
# {'speed': -0.02496260404586792, 'crashed': False, 'action': array([-0.0249626 , -0.01290619], dtype=float32), 'is_success': True}
# True
# {'speed': -0.025699079036712646, 'crashed': False, 'action': array([-0.02569908, -0.00342727], dtype=float32), 'is_success': True}
# True
# {'speed': -0.02991539239883423, 'crashed': False, 'action': array([-0.02991539, -0.01755512], dtype=float32), 'is_success': True}
# True
# {'speed': 0.013135671615600586, 'crashed': False, 'action': array([0.01313567, 0.03249931], dtype=float32), 'is_success': True}
# True
# {'speed': 0.01783430576324463, 'crashed': False, 'action': array([0.01783431, 0.0195359 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.002257704734802246, 'crashed': False, 'action': array([-0.0022577 ,  0.03647935], dtype=float32), 'is_success': True}
# True
# {'speed': -0.011956989765167236, 'crashed': False, 'action': array([-0.01195699,  0.0049535 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.028357505798339844, 'crashed': False, 'action': array([-0.02835751, -0.01599133], dtype=float32), 'is_success': True}
# True
# {'speed': 0.011412858963012695, 'crashed': False, 'action': array([0.01141286, 0.03426194], dtype=float32), 'is_success': True}
# True
# {'speed': -0.035848915576934814, 'crashed': False, 'action': array([-0.03584892, -0.00742531], dtype=float32), 'is_success': True}
# True
# {'speed': 0.005455732345581055, 'crashed': False, 'action': array([ 0.00545573, -0.01057094], dtype=float32), 'is_success': True}
# True
# {'speed': -0.010287940502166748, 'crashed': False, 'action': array([-0.01028794,  0.00239205], dtype=float32), 'is_success': True}
# True
# {'speed': 0.0045320987701416016, 'crashed': False, 'action': array([0.0045321 , 0.04543984], dtype=float32), 'is_success': True}
# True
# {'speed': -0.014531075954437256, 'crashed': False, 'action': array([-0.01453108, -0.011563  ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.008791327476501465, 'crashed': False, 'action': array([0.00879133, 0.0103581 ], dtype=float32), 'is_success': True}
# True
# {'speed': -0.0009870529174804688, 'crashed': False, 'action': array([-0.00098705,  0.00890899], dtype=float32), 'is_success': True}
# True
# {'speed': 0.007109522819519043, 'crashed': False, 'action': array([0.00710952, 0.00129998], dtype=float32), 'is_success': True}
# True
# {'speed': -0.016678333282470703, 'crashed': False, 'action': array([-0.01667833,  0.00626242], dtype=float32), 'is_success': True}
# True
# {'speed': 0.008508443832397461, 'crashed': False, 'action': array([0.00850844, 0.04145491], dtype=float32), 'is_success': True}
# True
# {'speed': -0.01648271083831787, 'crashed': False, 'action': array([-0.01648271, -0.02086198], dtype=float32), 'is_success': True}
# True
# {'speed': 0.0015006065368652344, 'crashed': False, 'action': array([ 0.00150061, -0.00217497], dtype=float32), 'is_success': True}
# True
# {'speed': 0.006268739700317383, 'crashed': False, 'action': array([0.00626874, 0.026142  ], dtype=float32), 'is_success': True}
# True
# {'speed': 0.0006232261657714844, 'crashed': False, 'action': array([ 0.00062323, -0.01009774], dtype=float32), 'is_success': True}
# True
# {'speed': -0.03257417678833008, 'crashed': False, 'action': array([-0.03257418, -0.02141136], dtype=float32), 'is_success': True}
# True
# {'speed': 0.021986961364746094, 'crashed': False, 'action': array([0.02198696, 0.06022656], dtype=float32), 'is_success': True}
# True
# {'speed': -0.014974415302276611, 'crashed': False, 'action': array([-0.01497442,  0.00040853], dtype=float32), 'is_success': True}
# True
# {'speed': 0.013748526573181152, 'crashed': False, 'action': array([0.01374853, 0.03094685], dtype=float32), 'is_success': True}
# True
# The average of rewards:  -0.4656492526600252

# %% [markdown]
# The reward for the agent taking the random actions in the parking environment is -0.48 to -0.43.

# %% [markdown]
# In conclusion, the agents that I deployed on the parking environment performed very poorly. The value of the average over all the rewards was in the negative. However, the results of the HER policy is better than the agent taking random actions.
#
#
# When the timesteps for HER was in 100s, it performed worse than the agent who took random action. It was mandatory to pick an agent with timesteps with a minimum of 1000, for the agent to achieve a performance which was better than the agent taking random actions.

# %% [markdown]
# # Merge setup

# %%
# Setting up the environment for roundabout
env = gym.make('merge-v0')

# %% [markdown]
# #### Using the env.config to look at the configurations available and the default values for this configuration.

# %%
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'high_speed_reward': 0.2,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'merging_speed_reward': -0.5,
#  'observation': {'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %%
env.config["collision_reward"] = -5
env.config['high_speed_reward'] = 1
env.reset()
# Out:
# array([[ 1.    ,  0.15  ,  0.5   ,  0.375 ,  0.    ],
#        [ 1.    ,  0.2   ,  0.    ,  0.0125,  0.    ],
#        [ 1.    ,  0.3   , -0.5   , -0.0125,  0.    ],
#        [ 1.    ,  0.4   ,  1.    , -0.125 ,  0.    ],
#        [ 0.    ,  0.    ,  0.    ,  0.    ,  0.    ]], dtype=float32)

# %% [markdown]
# ## GREEDY WITH Merge

# %% [markdown]
# Let us check the performance of an agent who takes random actions in the merge environment. In this environment we are checking if the cars can merge and unmerge without any human interruption.

# %% [markdown]
# ### Performance of agents taking random actions
#
# Reward function: We will look at the reward function to evaluate the performance of the agent taking greedy actions. I take the reward from each loop and then find the average of all the rewards.
#
# Number of crashes: The second method to evaluate the performance of the agent taking the greedy function is to count the number of crashes.

# %%
def Average(l): 
    avg = mean(l) 
    return avg


crashcount = 0
for i in range(100):
    done = False
    env.reset()
    total_reward = []
    while not done:
        env.render()
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        if info['crashed']==True : crashcount +=1
        total_reward.append(reward)
        print(info)
        print(done)
        
rewards_average = Average(total_reward) 
  
print("The average of rewards: ",rewards_average)
print("Number of Crashes: ", crashcount)
env.close()
# Out:
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 10.04036906164168, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 24.174774906282668, 'crashed': False, 'action': 3}
# False
# {'speed': 20.713419913696157, 'crashed': False, 'action': 4}
# False
# {'speed': 20.121915069598668, 'crashed': False, 'action': 0}
# False
# {'speed': 20.020833851018036, 'crashed': False, 'action': 4}
# False
# {'speed': 20.003560260020937, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000608406549787, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000103969521227, 'crashed': False, 'action': 1}
# False
# {'speed': 24.14557659403723, 'crashed': False, 'action': 3}
# False
# {'speed': 24.85398909253177, 'crashed': False, 'action': 1}
# False
# {'speed': 24.975048453786595, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 2}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 2}
# False
# {'speed': 20.0043885354593, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000749949077232, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000128157473867, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000021900604466, 'crashed': False, 'action': 2}
# False
# {'speed': 20.00000374255563, 'crashed': False, 'action': 0}
# False
# {'speed': 24.145559466428026, 'crashed': False, 'action': 3}
# False
# {'speed': 28.999544992494165, 'crashed': False, 'action': 3}
# False
# {'speed': 29.829034009944447, 'crashed': False, 'action': 0}
# False
# {'speed': 29.970783923778296, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 2}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 24.146412017864034, 'crashed': False, 'action': 3}
# False
# {'speed': 20.708573029765393, 'crashed': False, 'action': 4}
# False
# {'speed': 20.121086794160302, 'crashed': False, 'action': 2}
# False
# {'speed': 20.02069230849059, 'crashed': False, 'action': 1}
# False
# {'speed': 20.00353607206829, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00060427311326, 'crashed': False, 'action': 0}
# False
# {'speed': 20.000103263165556, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 1}
# False
# {'speed': 29.14628749675384, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854110577442004, 'crashed': False, 'action': 0}
# False
# {'speed': 29.97506921412844, 'crashed': False, 'action': 0}
# False
# {'speed': 29.99573962201457, 'crashed': False, 'action': 2}
# False
# {'speed': 29.99927195152723, 'crashed': False, 'action': 3}
# False
# {'speed': 29.999875585081767, 'crashed': False, 'action': 0}
# False
# {'speed': 29.999978738954262, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 1}
# False
# {'speed': 10.04036906164168, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 1}
# False
# {'speed': 29.14628749675384, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854110577442004, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97506921412844, 'crashed': False, 'action': 3}
# False
# {'speed': 29.99573962201457, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 1}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 3}
# False
# {'speed': 29.996464655535434, 'crashed': False, 'action': 2}
# False
# {'speed': 11.418015606919838, 'crashed': True, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 2}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 1}
# False
# {'speed': 25.850905828666136, 'crashed': False, 'action': 4}
# False
# {'speed': 25.145409794893848, 'crashed': False, 'action': 1}
# False
# {'speed': 20.87928999627746, 'crashed': False, 'action': 4}
# False
# {'speed': 20.15026031518828, 'crashed': False, 'action': 4}
# False
# {'speed': 10.074062805251126, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 2}
# False
# {'speed': 25.00072866988454, 'crashed': False, 'action': 0}
# False
# {'speed': 29.145683347979496, 'crashed': False, 'action': 3}
# False
# {'speed': 25.7084485086552, 'crashed': False, 'action': 4}
# False
# {'speed': 29.26662434183691, 'crashed': False, 'action': 3}
# False
# {'speed': 29.874674728458725, 'crashed': False, 'action': 2}
# False
# {'speed': 29.97858338559227, 'crashed': False, 'action': 1}
# False
# {'speed': 11.200498647779536, 'crashed': True, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 25.733379294526763, 'crashed': False, 'action': 4}
# False
# {'speed': 25.125325892953043, 'crashed': False, 'action': 0}
# False
# {'speed': 20.875857893730387, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14967380924296, 'crashed': False, 'action': 2}
# False
# {'speed': 20.025577493031296, 'crashed': False, 'action': 1}
# False
# {'speed': 24.14992971949958, 'crashed': False, 'action': 3}
# False
# {'speed': 20.709174163587836, 'crashed': False, 'action': 4}
# False
# {'speed': 20.12118952085799, 'crashed': False, 'action': 0}
# False
# {'speed': 20.02070986327461, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00072866988454, 'crashed': False, 'action': 0}
# False
# {'speed': 29.145683347979496, 'crashed': False, 'action': 3}
# False
# {'speed': 25.7084485086552, 'crashed': False, 'action': 4}
# False
# {'speed': 20.97550668809831, 'crashed': False, 'action': 4}
# False
# {'speed': 20.166702615795113, 'crashed': False, 'action': 1}
# False
# {'speed': 20.028487515720787, 'crashed': False, 'action': 1}
# False
# {'speed': 20.00486818127041, 'crashed': False, 'action': 2}
# False
# {'speed': 24.14639074177244, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854128220800963, 'crashed': False, 'action': 0}
# False
# {'speed': 24.975072229170905, 'crashed': False, 'action': 1}
# False
# {'speed': 24.995740137249854, 'crashed': False, 'action': 0}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 20.858705187479806, 'crashed': False, 'action': 4}
# False
# {'speed': 24.292301440422033, 'crashed': False, 'action': 3}
# False
# {'speed': 13.248417498597325, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 24.295836784886596, 'crashed': False, 'action': 3}
# False
# {'speed': 29.0252256181499, 'crashed': False, 'action': 3}
# False
# {'speed': 25.68786369985755, 'crashed': False, 'action': 4}
# False
# {'speed': 25.11754781333206, 'crashed': False, 'action': 1}
# False
# {'speed': 25.02008753830448, 'crashed': False, 'action': 1}
# False
# {'speed': 25.003432723958838, 'crashed': False, 'action': 1}
# False
# {'speed': 25.000586612137283, 'crashed': False, 'action': 0}
# False
# {'speed': 29.145659071981854, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 1}
# False
# {'speed': 24.174774906282668, 'crashed': False, 'action': 3}
# False
# {'speed': 29.004537567434753, 'crashed': False, 'action': 3}
# False
# {'speed': 29.829887182262283, 'crashed': False, 'action': 3}
# False
# {'speed': 29.970929720889522, 'crashed': False, 'action': 0}
# False
# {'speed': 29.99503223132272, 'crashed': False, 'action': 0}
# False
# {'speed': 29.99915106678071, 'crashed': False, 'action': 1}
# False
# {'speed': 29.99985492730084, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 0}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 3}
# False
# {'speed': 25.850905828666136, 'crashed': False, 'action': 4}
# False
# {'speed': 29.290968621763145, 'crashed': False, 'action': 3}
# False
# {'speed': 29.87883487947856, 'crashed': False, 'action': 1}
# False
# {'speed': 29.979294306455827, 'crashed': False, 'action': 1}
# False
# {'speed': 29.996461640583522, 'crashed': False, 'action': 2}
# False
# {'speed': 29.999395336005843, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 1}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 1}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 0}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# {'speed': 29.14628749675384, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854110577442004, 'crashed': False, 'action': 2}
# False
# {'speed': 25.829510387259138, 'crashed': False, 'action': 4}
# False
# {'speed': 20.996194738813465, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170237960259684, 'crashed': False, 'action': 2}
# False
# {'speed': 20.029091664495134, 'crashed': False, 'action': 0}
# False
# {'speed': 20.00497142318791, 'crashed': False, 'action': 4}
# False
# {'speed': 24.14640838460146, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97577660482028, 'crashed': False, 'action': 0}
# False
# {'speed': 29.995860506761083, 'crashed': False, 'action': 0}
# False
# {'speed': 29.999292609308153, 'crashed': False, 'action': 0}
# False
# {'speed': 25.85432028838418, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29155211275657, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97577660482028, 'crashed': False, 'action': 2}
# False
# {'speed': 25.850301679891786, 'crashed': False, 'action': 4}
# False
# {'speed': 25.145306552976347, 'crashed': False, 'action': 0}
# False
# {'speed': 25.024831180317737, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004243356568182, 'crashed': False, 'action': 0}
# False
# {'speed': 20.855166312843533, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 25.733379294526763, 'crashed': False, 'action': 4}
# False
# {'speed': 20.979767066083742, 'crashed': False, 'action': 4}
# False
# {'speed': 20.167430664267883, 'crashed': False, 'action': 4}
# False
# {'speed': 24.17417075750832, 'crashed': False, 'action': 3}
# False
# {'speed': 24.858875498647954, 'crashed': False, 'action': 1}
# False
# {'speed': 20.830324656232154, 'crashed': False, 'action': 4}
# False
# {'speed': 24.28745154153937, 'crashed': False, 'action': 3}
# False
# {'speed': 29.023792678717385, 'crashed': False, 'action': 3}
# False
# {'speed': 25.6876188273676, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 25.71269124381162, 'crashed': False, 'action': 4}
# False
# {'speed': 25.121790548488473, 'crashed': False, 'action': 0}
# False
# {'speed': 25.020812571825346, 'crashed': False, 'action': 0}
# False
# {'speed': 29.149115450526565, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854593841469825, 'crashed': False, 'action': 1}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 2}
# False
# {'speed': 25.83375312241555, 'crashed': False, 'action': 4}
# False
# {'speed': 29.288037426072925, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878333972621718, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97920870736735, 'crashed': False, 'action': 1}
# False
# {'speed': 29.99644701270641, 'crashed': False, 'action': 1}
# False
# {'speed': 29.99939283627375, 'crashed': False, 'action': 1}
# False
# {'speed': 29.999896242862693, 'crashed': False, 'action': 3}
# False
# {'speed': 25.854423442256678, 'crashed': False, 'action': 4}
# False
# {'speed': 25.14601091367043, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 2}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 2}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 0}
# False
# {'speed': 24.146412017864034, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854131856634694, 'crashed': False, 'action': 0}
# False
# {'speed': 24.97507285049211, 'crashed': False, 'action': 1}
# False
# {'speed': 24.995740243426336, 'crashed': False, 'action': 2}
# False
# {'speed': 29.144830884588487, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85386165956053, 'crashed': False, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 2}
# False
# {'speed': 20.85516984301524, 'crashed': False, 'action': 4}
# False
# {'speed': 10.270280665163314, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 1}
# False
# {'speed': 25.830217777950978, 'crashed': False, 'action': 4}
# False
# {'speed': 25.141874450429277, 'crashed': False, 'action': 2}
# False
# {'speed': 20.878685847503117, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150157073270783, 'crashed': False, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 24.316524835601754, 'crashed': False, 'action': 3}
# False
# {'speed': 29.02876096261447, 'crashed': False, 'action': 3}
# False
# {'speed': 29.834026675501196, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97163711158137, 'crashed': False, 'action': 3}
# False
# {'speed': 29.995153116069243, 'crashed': False, 'action': 0}
# False
# {'speed': 29.999171724561634, 'crashed': False, 'action': 2}
# False
# {'speed': 29.999858457472552, 'crashed': False, 'action': 3}
# False
# {'speed': 29.99997581204736, 'crashed': False, 'action': 0}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 24.316524835601754, 'crashed': False, 'action': 3}
# False
# {'speed': 24.883202135745172, 'crashed': False, 'action': 0}
# False
# {'speed': 20.83448179230009, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14260312031382, 'crashed': False, 'action': 4}
# False
# {'speed': 24.169928022351908, 'crashed': False, 'action': 3}
# False
# {'speed': 24.85815046512709, 'crashed': False, 'action': 1}
# False
# {'speed': 24.975759583403025, 'crashed': False, 'action': 0}
# False
# {'speed': 24.995857598001137, 'crashed': False, 'action': 0}
# False
# {'speed': 24.9992921122353, 'crashed': False, 'action': 2}
# False
# {'speed': 24.999879030309575, 'crashed': False, 'action': 1}
# False
# {'speed': 24.99997932770316, 'crashed': False, 'action': 1}
# False
# {'speed': 20.85443764047839, 'crashed': False, 'action': 4}
# False
# {'speed': 20.146013339979476, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 4}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 0}
# False
# {'speed': 20.0043885354593, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000749949077232, 'crashed': False, 'action': 1}
# False
# {'speed': 10.032445260140856, 'crashed': True, 'action': 2}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 29.14982284121841, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854714726216347, 'crashed': False, 'action': 3}
# False
# {'speed': 29.975172456045936, 'crashed': False, 'action': 0}
# False
# {'speed': 25.85019843797428, 'crashed': False, 'action': 4}
# False
# {'speed': 20.999730083278028, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170842109034023, 'crashed': False, 'action': 2}
# False
# {'speed': 20.029194906412627, 'crashed': False, 'action': 2}
# False
# {'speed': 20.004989066016932, 'crashed': False, 'action': 0}
# False
# {'speed': 20.000852572684064, 'crashed': False, 'action': 0}
# False
# {'speed': 20.000145694640867, 'crashed': False, 'action': 0}
# False
# {'speed': 20.000024897499976, 'crashed': False, 'action': 4}
# False
# {'speed': 24.145563081559114, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 24.145583742425668, 'crashed': False, 'action': 3}
# False
# {'speed': 24.85399031410725, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 3}
# False
# {'speed': 25.83375312241555, 'crashed': False, 'action': 4}
# False
# {'speed': 29.288037426072925, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878333972621718, 'crashed': False, 'action': 0}
# False
# {'speed': 29.97920870736735, 'crashed': False, 'action': 1}
# False
# {'speed': 29.99644701270641, 'crashed': False, 'action': 2}
# False
# {'speed': 29.99939283627375, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 2}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 0}
# False
# {'speed': 20.0043885354593, 'crashed': False, 'action': 1}
# False
# {'speed': 20.000749949077232, 'crashed': False, 'action': 1}
# False
# {'speed': 24.145686984343165, 'crashed': False, 'action': 3}
# False
# {'speed': 28.99956678380557, 'crashed': False, 'action': 3}
# False
# {'speed': 29.829037733823185, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 25.733379294526763, 'crashed': False, 'action': 4}
# False
# {'speed': 29.270884719822345, 'crashed': False, 'action': 3}
# False
# {'speed': 29.875402776931494, 'crashed': False, 'action': 0}
# False
# {'speed': 29.978707800510506, 'crashed': False, 'action': 1}
# False
# {'speed': 29.996361413617933, 'crashed': False, 'action': 0}
# False
# {'speed': 29.99937820839663, 'crashed': False, 'action': 2}
# False
# {'speed': 29.999893743130592, 'crashed': False, 'action': 0}
# False
# {'speed': 29.999981841951172, 'crashed': False, 'action': 3}
# False
# {'speed': 25.854438070133792, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 25.71269124381162, 'crashed': False, 'action': 4}
# False
# {'speed': 25.121790548488473, 'crashed': False, 'action': 1}
# False
# {'speed': 25.020812571825346, 'crashed': False, 'action': 0}
# False
# {'speed': 25.003556623657268, 'crashed': False, 'action': 1}
# False
# {'speed': 29.14616661200732, 'crashed': False, 'action': 3}
# False
# {'speed': 25.708531092791777, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 20.858705187479806, 'crashed': False, 'action': 4}
# False
# {'speed': 20.146742613552732, 'crashed': False, 'action': 4}
# False
# {'speed': 20.02507658617445, 'crashed': False, 'action': 2}
# False
# {'speed': 24.1498441204111, 'crashed': False, 'action': 3}
# False
# {'speed': 29.000277189449317, 'crashed': False, 'action': 3}
# False
# {'speed': 29.829159133789506, 'crashed': False, 'action': 0}
# False
# {'speed': 29.97080530597129, 'crashed': False, 'action': 0}
# False
# {'speed': 29.995010970276986, 'crashed': False, 'action': 0}
# False
# {'speed': 21.246279786352957, 'crashed': True, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 24.295836784886596, 'crashed': False, 'action': 3}
# False
# {'speed': 20.734107964411304, 'crashed': False, 'action': 4}
# False
# {'speed': 20.125450414063238, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 2}
# False
# {'speed': 25.00072866988454, 'crashed': False, 'action': 0}
# False
# {'speed': 29.145683347979496, 'crashed': False, 'action': 3}
# False
# {'speed': 29.8540073355245, 'crashed': False, 'action': 3}
# False
# {'speed': 29.975051571299417, 'crashed': False, 'action': 3}
# False
# {'speed': 29.99573660706266, 'crashed': False, 'action': 2}
# False
# {'speed': 25.853712609438123, 'crashed': False, 'action': 4}
# False
# {'speed': 25.145889440704956, 'crashed': False, 'action': 2}
# False
# {'speed': 13.474706870023146, 'crashed': True, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 1}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 2}
# False
# {'speed': 24.14570462717219, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854010971888172, 'crashed': False, 'action': 2}
# False
# {'speed': 24.975052192711182, 'crashed': False, 'action': 1}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00072866988454, 'crashed': False, 'action': 2}
# False
# {'speed': 25.000124521110198, 'crashed': False, 'action': 2}
# False
# {'speed': 29.145580106061995, 'crashed': False, 'action': 3}
# False
# {'speed': 29.853989692695478, 'crashed': False, 'action': 1}
# False
# {'speed': 29.97504855634751, 'crashed': False, 'action': 0}
# False
# {'speed': 29.995736091842854, 'crashed': False, 'action': 0}
# False
# {'speed': 29.99927134826242, 'crashed': False, 'action': 3}
# False
# {'speed': 29.99987548199091, 'crashed': False, 'action': 0}
# False
# {'speed': 29.999978721337246, 'crashed': False, 'action': 2}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 2}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 3}
# False
# {'speed': 25.850905828666136, 'crashed': False, 'action': 4}
# False
# {'speed': 25.145409794893848, 'crashed': False, 'action': 2}
# False
# {'speed': 25.02484882314676, 'crashed': False, 'action': 2}
# False
# {'speed': 25.004246371520086, 'crashed': False, 'action': 1}
# False
# {'speed': 25.000725654932634, 'crashed': False, 'action': 1}
# False
# {'speed': 29.145682832759686, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854007247479494, 'crashed': False, 'action': 1}
# False
# {'speed': 29.975051556253558, 'crashed': False, 'action': 2}
# False
# {'speed': 16.116623314623684, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 2}
# False
# {'speed': 29.996464655535434, 'crashed': False, 'action': 0}
# False
# {'speed': 29.999395851225657, 'crashed': False, 'action': 3}
# False
# {'speed': 25.854337931213202, 'crashed': False, 'action': 4}
# False
# {'speed': 21.00043747396988, 'crashed': False, 'action': 4}
# False
# {'speed': 24.31652182064985, 'crashed': False, 'action': 3}
# False
# {'speed': 24.88320162052536, 'crashed': False, 'action': 0}
# False
# {'speed': 29.125599357993686, 'crashed': False, 'action': 3}
# False
# {'speed': 25.705016391062276, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 20.858705187479806, 'crashed': False, 'action': 4}
# False
# {'speed': 24.292301440422033, 'crashed': False, 'action': 3}
# False
# {'speed': 24.879062642506256, 'crashed': False, 'action': 1}
# False
# {'speed': 24.979333228477543, 'crashed': False, 'action': 0}
# False
# {'speed': 24.996468291899102, 'crashed': False, 'action': 2}
# False
# {'speed': 29.14495529950672, 'crashed': False, 'action': 3}
# False
# {'speed': 29.853882920606267, 'crashed': False, 'action': 2}
# False
# {'speed': 29.975030310253675, 'crashed': False, 'action': 1}
# False
# {'speed': 29.995732973800088, 'crashed': False, 'action': 1}
# False
# {'speed': 29.999270815425593, 'crashed': False, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 20.858705187479806, 'crashed': False, 'action': 4}
# False
# {'speed': 24.292301440422033, 'crashed': False, 'action': 3}
# False
# {'speed': 24.879062642506256, 'crashed': False, 'action': 2}
# False
# {'speed': 24.979333228477543, 'crashed': False, 'action': 1}
# False
# {'speed': 24.996468291899102, 'crashed': False, 'action': 2}
# False
# {'speed': 24.999396472637425, 'crashed': False, 'action': 0}
# False
# {'speed': 24.99989686427446, 'crashed': False, 'action': 1}
# False
# {'speed': 24.999982375317934, 'crashed': False, 'action': 2}
# False
# {'speed': 20.854438161279898, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 29.14982284121841, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854714726216347, 'crashed': False, 'action': 2}
# False
# {'speed': 25.829613629176635, 'crashed': False, 'action': 4}
# False
# {'speed': 25.14177120851178, 'crashed': False, 'action': 2}
# False
# {'speed': 20.878668204674096, 'crashed': False, 'action': 4}
# False
# {'speed': 24.295712885188177, 'crashed': False, 'action': 3}
# False
# {'speed': 20.734086791410576, 'crashed': False, 'action': 4}
# False
# {'speed': 20.125446795846518, 'crashed': False, 'action': 4}
# False
# {'speed': 20.021437381481714, 'crashed': False, 'action': 4}
# False
# {'speed': 20.003663396276416, 'crashed': False, 'action': 4}
# False
# {'speed': 24.14618485819171, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854093037719313, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 0}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 2}
# False
# {'speed': 20.85516984301524, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14613846477839, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 2}
# False
# {'speed': 25.83375312241555, 'crashed': False, 'action': 4}
# False
# {'speed': 20.996919772334326, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170361859958106, 'crashed': False, 'action': 1}
# False
# {'speed': 20.02911283749587, 'crashed': False, 'action': 1}
# False
# {'speed': 24.150533868273925, 'crashed': False, 'action': 3}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 25.733379294526763, 'crashed': False, 'action': 4}
# False
# {'speed': 25.125325892953043, 'crashed': False, 'action': 0}
# False
# {'speed': 20.875857893730387, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14967380924296, 'crashed': False, 'action': 4}
# False
# {'speed': 20.025577493031296, 'crashed': False, 'action': 0}
# False
# {'speed': 24.14992971949958, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854732990457133, 'crashed': False, 'action': 0}
# False
# {'speed': 20.8296167503205, 'crashed': False, 'action': 4}
# False
# {'speed': 20.141771741878543, 'crashed': False, 'action': 1}
# False
# {'speed': 20.024227122689492, 'crashed': False, 'action': 1}
# False
# {'speed': 20.004140130226478, 'crashed': False, 'action': 0}
# False
# {'speed': 20.000707499545527, 'crashed': False, 'action': 0}
# False
# {'speed': 20.000120903348336, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97577660482028, 'crashed': False, 'action': 3}
# False
# {'speed': 29.995860506761083, 'crashed': False, 'action': 3}
# False
# {'speed': 29.999292609308153, 'crashed': False, 'action': 1}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 2}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 1}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 2}
# False
# {'speed': 24.14570462717219, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854010971888172, 'crashed': False, 'action': 2}
# False
# {'speed': 24.975052192711182, 'crashed': False, 'action': 2}
# False
# {'speed': 24.995736713254622, 'crashed': False, 'action': 2}
# False
# {'speed': 29.144830281323674, 'crashed': False, 'action': 3}
# False
# {'speed': 29.853861556469674, 'crashed': False, 'action': 0}
# False
# {'speed': 25.82946783250479, 'crashed': False, 'action': 4}
# False
# {'speed': 29.287305120445215, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# ...
# {'speed': 20.87440419085493, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 4}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 4}
# False
# {'speed': 20.0043885354593, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000749949077232, 'crashed': False, 'action': 2}
# False
# {'speed': 20.000128157473867, 'crashed': False, 'action': 4}
# False
# {'speed': 24.14558072747376, 'crashed': False, 'action': 3}
# False
# {'speed': 24.85398979888744, 'crashed': False, 'action': 0}
# False
# {'speed': 24.975048574494465, 'crashed': False, 'action': 0}
# False
# {'speed': 20.850177268074656, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14528529246055, 'crashed': False, 'action': 2}
# False
# {'speed': 24.170386374015024, 'crashed': False, 'action': 3}
# False
# {'speed': 29.003787618902937, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00072866988454, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000124521110198, 'crashed': False, 'action': 1}
# False
# {'speed': 25.000021279192694, 'crashed': False, 'action': 1}
# False
# {'speed': 20.854444809494375, 'crashed': False, 'action': 4}
# False
# {'speed': 20.146014565079962, 'crashed': False, 'action': 4}
# False
# {'speed': 20.024952171256217, 'crashed': False, 'action': 1}
# False
# {'speed': 24.149822859365365, 'crashed': False, 'action': 3}
# False
# {'speed': 24.85471472931745, 'crashed': False, 'action': 2}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# {'speed': 20.85516984301524, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14613846477839, 'crashed': False, 'action': 0}
# False
# {'speed': 20.024973344256956, 'crashed': False, 'action': 1}
# False
# {'speed': 20.00426765071278, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00072929129631, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000124627302156, 'crashed': False, 'action': 1}
# False
# {'speed': 24.14558012420895, 'crashed': False, 'action': 3}
# False
# {'speed': 28.99954852266588, 'crashed': False, 'action': 3}
# False
# {'speed': 15.858013811887735, 'crashed': True, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 29.14982284121841, 'crashed': False, 'action': 3}
# False
# {'speed': 29.854714726216347, 'crashed': False, 'action': 2}
# False
# {'speed': 24.362370125541286, 'crashed': True, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 2}
# False
# {'speed': 29.996464655535434, 'crashed': False, 'action': 3}
# False
# {'speed': 29.999395851225657, 'crashed': False, 'action': 3}
# False
# {'speed': 25.854337931213202, 'crashed': False, 'action': 4}
# False
# {'speed': 25.145996300839172, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024949050112355, 'crashed': False, 'action': 0}
# False
# {'speed': 25.004263499129298, 'crashed': False, 'action': 1}
# False
# {'speed': 25.000728581839535, 'crashed': False, 'action': 0}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97577660482028, 'crashed': False, 'action': 2}
# False
# {'speed': 29.995860506761083, 'crashed': False, 'action': 1}
# False
# {'speed': 29.999292609308153, 'crashed': False, 'action': 2}
# False
# {'speed': 29.99987911525348, 'crashed': False, 'action': 3}
# False
# {'speed': 29.999979342219078, 'crashed': False, 'action': 2}
# False
# {'speed': 29.999996469828286, 'crashed': False, 'action': 3}
# False
# {'speed': 29.99999939673519, 'crashed': False, 'action': 0}
# False
# {'speed': 29.99999989690914, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 0}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 0}
# False
# {'speed': 29.996464655535434, 'crashed': False, 'action': 1}
# False
# {'speed': 29.999395851225657, 'crashed': False, 'action': 0}
# False
# {'speed': 17.274744507922563, 'crashed': True, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 24.316524835601754, 'crashed': False, 'action': 3}
# False
# {'speed': 29.02876096261447, 'crashed': False, 'action': 3}
# False
# {'speed': 29.834026675501196, 'crashed': False, 'action': 1}
# False
# {'speed': 25.826078284712068, 'crashed': False, 'action': 4}
# False
# {'speed': 16.714907951203095, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 2}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00072866988454, 'crashed': False, 'action': 1}
# False
# {'speed': 25.000124521110198, 'crashed': False, 'action': 2}
# False
# {'speed': 25.000021279192694, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000003636363672, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00000062141177, 'crashed': False, 'action': 2}
# False
# {'speed': 25.000000106191962, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00000001814696, 'crashed': False, 'action': 1}
# False
# {'speed': 25.0000000031011, 'crashed': False, 'action': 2}
# False
# {'speed': 25.00000000052994, 'crashed': False, 'action': 1}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 25.733379294526763, 'crashed': False, 'action': 4}
# False
# {'speed': 25.125325892953043, 'crashed': False, 'action': 1}
# False
# {'speed': 20.875857893730387, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14967380924296, 'crashed': False, 'action': 4}
# False
# {'speed': 10.073899546085409, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97577660482028, 'crashed': False, 'action': 2}
# False
# {'speed': 25.850301679891786, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29086537984565, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878817236649542, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97929129150392, 'crashed': False, 'action': 3}
# False
# {'speed': 29.996461125363716, 'crashed': False, 'action': 1}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 2}
# False
# {'speed': 20.858705187479806, 'crashed': False, 'action': 4}
# False
# {'speed': 20.146742613552732, 'crashed': False, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 2}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 1}
# False
# {'speed': 24.1499473623286, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854736005409038, 'crashed': False, 'action': 0}
# False
# {'speed': 24.97517609240961, 'crashed': False, 'action': 2}
# False
# {'speed': 24.995757886255358, 'crashed': False, 'action': 1}
# False
# {'speed': 20.8537162458018, 'crashed': False, 'action': 4}
# False
# {'speed': 24.291448888986025, 'crashed': False, 'action': 3}
# False
# {'speed': 24.878916951496436, 'crashed': False, 'action': 0}
# False
# {'speed': 24.979308331598073, 'crashed': False, 'action': 0}
# False
# {'speed': 29.142022864184625, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 2}
# False
# {'speed': 25.830217777950978, 'crashed': False, 'action': 4}
# False
# {'speed': 29.28743327729858, 'crashed': False, 'action': 3}
# False
# {'speed': 25.73267190383492, 'crashed': False, 'action': 4}
# False
# {'speed': 20.97964618133722, 'crashed': False, 'action': 4}
# False
# {'speed': 20.167410006486957, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 22.76503703703704, 'crashed': True, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 2}
# False
# {'speed': 10.788664075647732, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 3}
# False
# {'speed': 29.97931194928485, 'crashed': False, 'action': 0}
# False
# {'speed': 29.996464655535434, 'crashed': False, 'action': 1}
# False
# {'speed': 29.999395851225657, 'crashed': False, 'action': 2}
# False
# {'speed': 29.9998967580825, 'crashed': False, 'action': 1}
# False
# {'speed': 29.999982357170982, 'crashed': False, 'action': 3}
# False
# {'speed': 29.999996985048092, 'crashed': False, 'action': 2}
# False
# {'speed': 29.99999948478019, 'crashed': False, 'action': 1}
# False
# {'speed': 29.999999911954998, 'crashed': False, 'action': 3}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 29.29157277053749, 'crashed': False, 'action': 3}
# False
# {'speed': 29.878938121396065, 'crashed': False, 'action': 2}
# False
# {'speed': 11.378250854827188, 'crashed': True, 'action': 3}
# True
# The average of rewards:  0.8999753679202842
# Number of Crashes:  23

# %% [markdown]
# The agent taking random actions in the merge environment performs really good in some environment and really poorly in others. The environment is thrown randomly. Overall the performance is between 0.76 to 0.96 which is a very high range. Overall this is not a reliable agent and we should consider agents that are policy-based. The crashes ranges from 14-38
#
# It can be seen that even with a higher avg-rewards value the number of crashed was very high.

# %% [markdown]
# ## DQN WITH Merge
#
# For more information on the algorithm look at the report attached with this notebook

# %% [markdown]
# ### Creating a DQN model for the merge agent
#
#
# I set the timesteps at 1000.

# %%
dqn_highway = DQN('MlpPolicy', env, verbose=1)

# %%
dqn_highway.learn(10000)
# Out:
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 100      |
# | mean 100 episode reward | 11.5     |
# | steps                   | 1210     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 200      |
# | mean 100 episode reward | 11.7     |
# | steps                   | 2421     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 300      |
# | mean 100 episode reward | 11.6     |
# | steps                   | 3621     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 400      |
# | mean 100 episode reward | 11.8     |
# | steps                   | 4865     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 500      |
# | mean 100 episode reward | 13.3     |
# | steps                   | 6417     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 600      |
# | mean 100 episode reward | 13.2     |
# | steps                   | 7985     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 700      |
# | mean 100 episode reward | 13.4     |
# | steps                   | 9583     |
# --------------------------------------

# %% [markdown]
# ## Performance of DQN on merge env

# %%
crashcount = 0
for i in range(100):
    done = False
    obs = env.reset()
    total_reward = []
    while not done:
        env.render()
        action, _states = dqn_highway.predict(obs)
        next_state, reward, done, info = env.step(action)
        if info['crashed']==True : crashcount +=1
        total_reward.append(reward)
        print(info)
        print(done)
        
rewards_average = Average(total_reward) 
  
print("The average of rewards: ",rewards_average)      
print("Number of Crashes: ", crashcount)
env.close()
# Out:
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# ...
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 4}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00499268423365, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000853190994736, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00014580030289, 'crashed': False, 'action': 4}
# False
# {'speed': 20.00002491555637, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000004257775444, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000727603734, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000124338918, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000021248056, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000003631044, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000620503, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000106038, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000018122, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000000000003094, 'crashed': False, 'action': 4}
# True
# The average of rewards:  0.8489159918247662
# Number of Crashes:  0

# %% [markdown]
# Performance of DQN is definitely better than the agent taking greedy actions, the rwards range from 0.91 to 0.98
#
# Moreover, when the average of the rewards have a value of 0.98-0.99 there are no crashes. The number of crashes go from 0-7

# %% [markdown]
# ## PPO WITH Merge
#
# More information on the algorithm can be found in the report.

# %% [markdown]
# ### Creating a ppo model
#
#
# I set the timesteps at 1000.

# %%
ppo_highway = PPO2('MlpPolicy', env, verbose=1)
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
ppo_highway.learn(10000)
# Out:
# --------------------------------------
# | approxkl           | 0.00016339326 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0627       |
# | fps                | 39            |
# | n_updates          | 1             |
# | policy_entropy     | 1.6092753     |
# | policy_loss        | -0.002627396  |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 15.065617     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.802517e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0463        |
# | fps                | 40             |
# | n_updates          | 2              |
# | policy_entropy     | 1.6084849      |
# | policy_loss        | -0.00033789547 |
# | serial_timesteps   | 256            |
# | time_elapsed       | 3.28           |
# | total_timesteps    | 256            |
# | value_loss         | 12.765794      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.2108119e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0406       |
# | fps                | 40            |
# | n_updates          | 3             |
# | policy_entropy     | 1.6078721     |
# | policy_loss        | 0.0001288699  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 6.4           |
# | total_timesteps    | 384           |
# | value_loss         | 11.672342     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.1812946e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.047        |
# | fps                | 40            |
# | n_updates          | 4             |
# | policy_entropy     | 1.6075962     |
# | policy_loss        | -0.0003135997 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 9.58          |
# | total_timesteps    | 512           |
# | value_loss         | 11.365355     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.8554078e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0452        |
# | fps                | 40             |
# | n_updates          | 5              |
# | policy_entropy     | 1.6075757      |
# | policy_loss        | -6.8044406e-05 |
# | serial_timesteps   | 640            |
# | time_elapsed       | 12.7           |
# | total_timesteps    | 640            |
# | value_loss         | 10.136051      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.0637536e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0192        |
# | fps                | 40             |
# | n_updates          | 6              |
# | policy_entropy     | 1.6075054      |
# | policy_loss        | -4.8867892e-05 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 15.9           |
# | total_timesteps    | 768            |
# | value_loss         | 9.027331       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.0294006e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00316      |
# | fps                | 40            |
# | n_updates          | 7             |
# | policy_entropy     | 1.6076927     |
# | policy_loss        | 0.0008638771  |
# | serial_timesteps   | 896           |
# | time_elapsed       | 19            |
# | total_timesteps    | 896           |
# | value_loss         | 8.102791      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.2565654e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0233        |
# | fps                | 40            |
# | n_updates          | 8             |
# | policy_entropy     | 1.6077313     |
# | policy_loss        | -0.0001301656 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 22.1          |
# | total_timesteps    | 1024          |
# | value_loss         | 7.5282245     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.353529e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0239         |
# | fps                | 38             |
# | n_updates          | 9              |
# | policy_entropy     | 1.607662       |
# | policy_loss        | -0.00022342836 |
# | serial_timesteps   | 1152           |
# | time_elapsed       | 25.3           |
# | total_timesteps    | 1152           |
# | value_loss         | 7.582374       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.6503763e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0537         |
# | fps                | 38             |
# | n_updates          | 10             |
# | policy_entropy     | 1.6081274      |
# | policy_loss        | -0.00022060855 |
# | serial_timesteps   | 1280           |
# | time_elapsed       | 28.6           |
# | total_timesteps    | 1280           |
# | value_loss         | 6.697161       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.426606e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0371         |
# | fps                | 38             |
# | n_updates          | 11             |
# | policy_entropy     | 1.6079954      |
# | policy_loss        | -0.00059505575 |
# | serial_timesteps   | 1408           |
# | time_elapsed       | 31.9           |
# | total_timesteps    | 1408           |
# | value_loss         | 4.7168756      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 3.155708e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0845         |
# | fps                | 38             |
# | n_updates          | 12             |
# | policy_entropy     | 1.6078068      |
# | policy_loss        | -0.00066823047 |
# | serial_timesteps   | 1536           |
# | time_elapsed       | 35.2           |
# | total_timesteps    | 1536           |
# | value_loss         | 5.1574903      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.4068867e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.107         |
# | fps                | 39            |
# | n_updates          | 13            |
# | policy_entropy     | 1.6070372     |
# | policy_loss        | -0.0014126616 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 38.6          |
# | total_timesteps    | 1664          |
# | value_loss         | 5.406878      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.5215566e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.094          |
# | fps                | 40             |
# | n_updates          | 14             |
# | policy_entropy     | 1.6060349      |
# | policy_loss        | 0.000114328344 |
# | serial_timesteps   | 1792           |
# | time_elapsed       | 41.8           |
# | total_timesteps    | 1792           |
# | value_loss         | 5.2146726      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.391684e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.176         |
# | fps                | 39            |
# | n_updates          | 15            |
# | policy_entropy     | 1.6062886     |
# | policy_loss        | -2.463872e-05 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 45            |
# | total_timesteps    | 1920          |
# | value_loss         | 4.4883323     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.05933e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.169         |
# | fps                | 39            |
# | n_updates          | 16            |
# | policy_entropy     | 1.6054187     |
# | policy_loss        | -0.0011621405 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 48.3          |
# | total_timesteps    | 2048          |
# | value_loss         | 4.4133606     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.5348745e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.183         |
# | fps                | 38            |
# | n_updates          | 17            |
# | policy_entropy     | 1.6054527     |
# | policy_loss        | -0.0003295316 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 51.5          |
# | total_timesteps    | 2176          |
# | value_loss         | 4.3648877     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.635074e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.248          |
# | fps                | 39             |
# | n_updates          | 18             |
# | policy_entropy     | 1.6055706      |
# | policy_loss        | -0.00031231483 |
# | serial_timesteps   | 2304           |
# | time_elapsed       | 54.8           |
# | total_timesteps    | 2304           |
# | value_loss         | 3.8504505      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.5387926e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.202          |
# | fps                | 38             |
# | n_updates          | 19             |
# | policy_entropy     | 1.6046062      |
# | policy_loss        | -0.00043384847 |
# | serial_timesteps   | 2432           |
# | time_elapsed       | 58.1           |
# | total_timesteps    | 2432           |
# | value_loss         | 4.0990043      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00010224041 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.281         |
# | fps                | 39            |
# | n_updates          | 20            |
# | policy_entropy     | 1.6050771     |
# | policy_loss        | -0.0028615566 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 61.4          |
# | total_timesteps    | 2560          |
# | value_loss         | 3.669982      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 2.600792e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.337        |
# | fps                | 39           |
# | n_updates          | 21           |
# | policy_entropy     | 1.6055727    |
# | policy_loss        | 0.0011707377 |
# | serial_timesteps   | 2688         |
# | time_elapsed       | 64.6         |
# | total_timesteps    | 2688         |
# | value_loss         | 3.4532905    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 3.070628e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.316         |
# | fps                | 40            |
# | n_updates          | 22            |
# | policy_entropy     | 1.6054862     |
# | policy_loss        | -0.0012996262 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 67.9          |
# | total_timesteps    | 2816          |
# | value_loss         | 3.53047       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.7626105e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.414         |
# | fps                | 39            |
# | n_updates          | 23            |
# | policy_entropy     | 1.6055615     |
# | policy_loss        | -0.0012414223 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 71            |
# | total_timesteps    | 2944          |
# | value_loss         | 3.070815      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023025296 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.519         |
# | fps                | 38            |
# | n_updates          | 24            |
# | policy_entropy     | 1.6039058     |
# | policy_loss        | -0.004145836  |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 74.2          |
# | total_timesteps    | 3072          |
# | value_loss         | 2.3310437     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019720626 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.388         |
# | fps                | 39            |
# | n_updates          | 25            |
# | policy_entropy     | 1.600012      |
# | policy_loss        | 0.0005090006  |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 77.5          |
# | total_timesteps    | 3200          |
# | value_loss         | 3.2411213     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.1310647e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.677          |
# | fps                | 39             |
# | n_updates          | 26             |
# | policy_entropy     | 1.6001985      |
# | policy_loss        | -0.00032671762 |
# | serial_timesteps   | 3328           |
# | time_elapsed       | 80.8           |
# | total_timesteps    | 3328           |
# | value_loss         | 2.1289124      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00022779312 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.493         |
# | fps                | 39            |
# | n_updates          | 27            |
# | policy_entropy     | 1.5978212     |
# | policy_loss        | -0.003401188  |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 84            |
# | total_timesteps    | 3456          |
# | value_loss         | 2.7953863     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029298663 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.589         |
# | fps                | 39            |
# | n_updates          | 28            |
# | policy_entropy     | 1.5947775     |
# | policy_loss        | -0.002584565  |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 87.3          |
# | total_timesteps    | 3584          |
# | value_loss         | 1.9473861     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018167098 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.452         |
# | fps                | 39            |
# | n_updates          | 29            |
# | policy_entropy     | 1.5885603     |
# | policy_loss        | -0.0006111425 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 90.5          |
# | total_timesteps    | 3712          |
# | value_loss         | 2.7388806     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021764042 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.661         |
# | fps                | 39            |
# | n_updates          | 30            |
# | policy_entropy     | 1.5889916     |
# | policy_loss        | -0.00273636   |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 93.8          |
# | total_timesteps    | 3840          |
# | value_loss         | 2.0988069     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003766488  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.565         |
# | fps                | 40            |
# | n_updates          | 31            |
# | policy_entropy     | 1.5829341     |
# | policy_loss        | -0.0012337295 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 97            |
# | total_timesteps    | 3968          |
# | value_loss         | 2.2906358     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00031517865 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.718         |
# | fps                | 40            |
# | n_updates          | 32            |
# | policy_entropy     | 1.573972      |
# | policy_loss        | -0.0022933083 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 100           |
# | total_timesteps    | 4096          |
# | value_loss         | 1.3669659     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00071505696 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.715         |
# | fps                | 40            |
# | n_updates          | 33            |
# | policy_entropy     | 1.561293      |
# | policy_loss        | -0.006112649  |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 103           |
# | total_timesteps    | 4224          |
# | value_loss         | 1.3643755     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00080801884 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.764         |
# | fps                | 40            |
# | n_updates          | 34            |
# | policy_entropy     | 1.5395051     |
# | policy_loss        | -0.0044628037 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 106           |
# | total_timesteps    | 4352          |
# | value_loss         | 1.3398424     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009382582 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.695        |
# | fps                | 40           |
# | n_updates          | 35           |
# | policy_entropy     | 1.5226321    |
# | policy_loss        | -0.004279631 |
# | serial_timesteps   | 4480         |
# | time_elapsed       | 110          |
# | total_timesteps    | 4480         |
# | value_loss         | 1.6046668    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0011040708 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.733        |
# | fps                | 40           |
# | n_updates          | 36           |
# | policy_entropy     | 1.4945585    |
# | policy_loss        | -0.004329701 |
# | serial_timesteps   | 4608         |
# | time_elapsed       | 113          |
# | total_timesteps    | 4608         |
# | value_loss         | 1.3633604    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0010730587 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.702        |
# | fps                | 40           |
# | n_updates          | 37           |
# | policy_entropy     | 1.4730475    |
# | policy_loss        | -0.009775405 |
# | serial_timesteps   | 4736         |
# | time_elapsed       | 116          |
# | total_timesteps    | 4736         |
# | value_loss         | 1.5305121    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001579647   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.811         |
# | fps                | 40            |
# | n_updates          | 38            |
# | policy_entropy     | 1.4451443     |
# | policy_loss        | -0.0015930231 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 119           |
# | total_timesteps    | 4864          |
# | value_loss         | 1.0058048     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014654053  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.635         |
# | fps                | 38            |
# | n_updates          | 39            |
# | policy_entropy     | 1.408131      |
# | policy_loss        | -0.0040137656 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 122           |
# | total_timesteps    | 4992          |
# | value_loss         | 1.954889      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017241811 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.815        |
# | fps                | 39           |
# | n_updates          | 40           |
# | policy_entropy     | 1.3809284    |
# | policy_loss        | -0.0070013   |
# | serial_timesteps   | 5120         |
# | time_elapsed       | 125          |
# | total_timesteps    | 5120         |
# | value_loss         | 1.0178424    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0024485982 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.468        |
# | fps                | 39           |
# | n_updates          | 41           |
# | policy_entropy     | 1.3597451    |
# | policy_loss        | -0.008272691 |
# | serial_timesteps   | 5248         |
# | time_elapsed       | 129          |
# | total_timesteps    | 5248         |
# | value_loss         | 2.8682969    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0026919995 |
# | clipfrac           | 0.017578125  |
# | explained_variance | 0.776        |
# | fps                | 39           |
# | n_updates          | 42           |
# | policy_entropy     | 1.2753069    |
# | policy_loss        | -0.011182778 |
# | serial_timesteps   | 5376         |
# | time_elapsed       | 132          |
# | total_timesteps    | 5376         |
# | value_loss         | 1.2286174    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00055128144 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.845         |
# | fps                | 39            |
# | n_updates          | 43            |
# | policy_entropy     | 1.2157762     |
# | policy_loss        | -0.0013663473 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 135           |
# | total_timesteps    | 5504          |
# | value_loss         | 0.8530588     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00051878404 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.84          |
# | fps                | 39            |
# | n_updates          | 44            |
# | policy_entropy     | 1.1861609     |
# | policy_loss        | -0.001887525  |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 138           |
# | total_timesteps    | 5632          |
# | value_loss         | 0.8746769     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0004728078   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.828          |
# | fps                | 39             |
# | n_updates          | 45             |
# | policy_entropy     | 1.1450112      |
# | policy_loss        | -0.00026693242 |
# | serial_timesteps   | 5760           |
# | time_elapsed       | 142            |
# | total_timesteps    | 5760           |
# | value_loss         | 1.0589604      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00074224174 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.891         |
# | fps                | 38            |
# | n_updates          | 46            |
# | policy_entropy     | 1.1277636     |
# | policy_loss        | -0.003433632  |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 145           |
# | total_timesteps    | 5888          |
# | value_loss         | 0.597215      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00034504913 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.872         |
# | fps                | 39            |
# | n_updates          | 47            |
# | policy_entropy     | 1.1092322     |
# | policy_loss        | -0.0019493154 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 148           |
# | total_timesteps    | 6016          |
# | value_loss         | 0.66207564    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0029526604 |
# | clipfrac           | 0.02734375   |
# | explained_variance | 0.928        |
# | fps                | 39           |
# | n_updates          | 48           |
# | policy_entropy     | 1.2091638    |
# | policy_loss        | -0.008592441 |
# | serial_timesteps   | 6144         |
# | time_elapsed       | 152          |
# | total_timesteps    | 6144         |
# | value_loss         | 0.41790733   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.003697154  |
# | clipfrac           | 0.005859375  |
# | explained_variance | 0.909        |
# | fps                | 39           |
# | n_updates          | 49           |
# | policy_entropy     | 1.3007944    |
# | policy_loss        | -0.007984031 |
# | serial_timesteps   | 6272         |
# | time_elapsed       | 155          |
# | total_timesteps    | 6272         |
# | value_loss         | 0.4874425    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0028876662 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.814        |
# | fps                | 40           |
# | n_updates          | 50           |
# | policy_entropy     | 1.3936158    |
# | policy_loss        | -0.006606343 |
# | serial_timesteps   | 6400         |
# | time_elapsed       | 158          |
# | total_timesteps    | 6400         |
# | value_loss         | 0.99869776   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00029937414 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.911         |
# | fps                | 39            |
# | n_updates          | 51            |
# | policy_entropy     | 1.4329295     |
# | policy_loss        | 0.0012356911  |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 161           |
# | total_timesteps    | 6528          |
# | value_loss         | 0.507741      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00046542377 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.86          |
# | fps                | 39            |
# | n_updates          | 52            |
# | policy_entropy     | 1.4101921     |
# | policy_loss        | -0.004195827  |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 164           |
# | total_timesteps    | 6656          |
# | value_loss         | 0.768744      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00064427534 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.441         |
# | fps                | 39            |
# | n_updates          | 53            |
# | policy_entropy     | 1.4172193     |
# | policy_loss        | -0.002647499  |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 168           |
# | total_timesteps    | 6784          |
# | value_loss         | 3.7640533     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0016382355 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.704        |
# | fps                | 39           |
# | n_updates          | 54           |
# | policy_entropy     | 1.4223938    |
# | policy_loss        | -0.006825353 |
# | serial_timesteps   | 6912         |
# | time_elapsed       | 171          |
# | total_timesteps    | 6912         |
# | value_loss         | 1.7443318    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0016656944 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.613        |
# | fps                | 40           |
# | n_updates          | 55           |
# | policy_entropy     | 1.4068458    |
# | policy_loss        | -0.010613151 |
# | serial_timesteps   | 7040         |
# | time_elapsed       | 174          |
# | total_timesteps    | 7040         |
# | value_loss         | 2.098011     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0022799948 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.927        |
# | fps                | 39           |
# | n_updates          | 56           |
# | policy_entropy     | 1.3784523    |
# | policy_loss        | -0.010545831 |
# | serial_timesteps   | 7168         |
# | time_elapsed       | 177          |
# | total_timesteps    | 7168         |
# | value_loss         | 0.41197088   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001426151   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.924         |
# | fps                | 39            |
# | n_updates          | 57            |
# | policy_entropy     | 1.3153986     |
# | policy_loss        | -0.0033128774 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 181           |
# | total_timesteps    | 7296          |
# | value_loss         | 0.37238982    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0028813197 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.845        |
# | fps                | 38           |
# | n_updates          | 58           |
# | policy_entropy     | 1.3127674    |
# | policy_loss        | -0.011941532 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 184          |
# | total_timesteps    | 7424         |
# | value_loss         | 0.8389323    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0004692817   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.921          |
# | fps                | 39             |
# | n_updates          | 59             |
# | policy_entropy     | 1.2908952      |
# | policy_loss        | 0.000102773425 |
# | serial_timesteps   | 7552           |
# | time_elapsed       | 187            |
# | total_timesteps    | 7552           |
# | value_loss         | 0.43776628     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00020107726 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.9           |
# | fps                | 38            |
# | n_updates          | 60            |
# | policy_entropy     | 1.2910267     |
# | policy_loss        | -0.0010077064 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 191           |
# | total_timesteps    | 7680          |
# | value_loss         | 0.54678786    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0016058428 |
# | clipfrac           | 0.025390625  |
# | explained_variance | 0.894        |
# | fps                | 39           |
# | n_updates          | 61           |
# | policy_entropy     | 1.297817     |
# | policy_loss        | -0.010832386 |
# | serial_timesteps   | 7808         |
# | time_elapsed       | 194          |
# | total_timesteps    | 7808         |
# | value_loss         | 0.59064764   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0027183876 |
# | clipfrac           | 0.05859375   |
# | explained_variance | 0.944        |
# | fps                | 38           |
# | n_updates          | 62           |
# | policy_entropy     | 1.3229922    |
# | policy_loss        | -0.013028962 |
# | serial_timesteps   | 7936         |
# | time_elapsed       | 197          |
# | total_timesteps    | 7936         |
# | value_loss         | 0.3256106    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0022457226 |
# | clipfrac           | 0.029296875  |
# | explained_variance | 0.862        |
# | fps                | 39           |
# | n_updates          | 63           |
# | policy_entropy     | 1.3226491    |
# | policy_loss        | -0.013809178 |
# | serial_timesteps   | 8064         |
# | time_elapsed       | 200          |
# | total_timesteps    | 8064         |
# | value_loss         | 0.75771093   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012559306  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.765         |
# | fps                | 39            |
# | n_updates          | 64            |
# | policy_entropy     | 1.3055387     |
# | policy_loss        | 0.00016178587 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 204           |
# | total_timesteps    | 8192          |
# | value_loss         | 1.3475522     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0014036407 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.899        |
# | fps                | 40           |
# | n_updates          | 65           |
# | policy_entropy     | 1.2945151    |
# | policy_loss        | -0.00706277  |
# | serial_timesteps   | 8320         |
# | time_elapsed       | 207          |
# | total_timesteps    | 8320         |
# | value_loss         | 0.5836451    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0018496641  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.902         |
# | fps                | 39            |
# | n_updates          | 66            |
# | policy_entropy     | 1.2718836     |
# | policy_loss        | -0.0052678203 |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 210           |
# | total_timesteps    | 8448          |
# | value_loss         | 0.5910437     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035628007 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.813         |
# | fps                | 39            |
# | n_updates          | 67            |
# | policy_entropy     | 1.272865      |
# | policy_loss        | 0.0005723238  |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 213           |
# | total_timesteps    | 8576          |
# | value_loss         | 1.1469481     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008506901  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.576         |
# | fps                | 39            |
# | n_updates          | 68            |
# | policy_entropy     | 1.2981253     |
# | policy_loss        | -0.0069168555 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 217           |
# | total_timesteps    | 8704          |
# | value_loss         | 2.557672      |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.001765356 |
# | clipfrac           | 0.0         |
# | explained_variance | 0.663       |
# | fps                | 40          |
# | n_updates          | 69          |
# | policy_entropy     | 1.3188369   |
# | policy_loss        | -0.00482329 |
# | serial_timesteps   | 8832        |
# | time_elapsed       | 220         |
# | total_timesteps    | 8832        |
# | value_loss         | 1.998293    |
# ------------------------------------
# --------------------------------------
# | approxkl           | 0.0003474655  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.941         |
# | fps                | 38            |
# | n_updates          | 70            |
# | policy_entropy     | 1.3107071     |
# | policy_loss        | -0.0018254417 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 223           |
# | total_timesteps    | 8960          |
# | value_loss         | 0.3493939     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00088892516 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.846         |
# | fps                | 39            |
# | n_updates          | 71            |
# | policy_entropy     | 1.3026524     |
# | policy_loss        | -0.0028972533 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 226           |
# | total_timesteps    | 9088          |
# | value_loss         | 0.87918115    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020026597  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.942         |
# | fps                | 39            |
# | n_updates          | 72            |
# | policy_entropy     | 1.2920871     |
# | policy_loss        | -0.0056136074 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 230           |
# | total_timesteps    | 9216          |
# | value_loss         | 0.36566803    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011092807 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.893        |
# | fps                | 39           |
# | n_updates          | 73           |
# | policy_entropy     | 1.3035561    |
# | policy_loss        | -0.005097566 |
# | serial_timesteps   | 9344         |
# | time_elapsed       | 233          |
# | total_timesteps    | 9344         |
# | value_loss         | 0.6643809    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0007567037  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.788         |
# | fps                | 38            |
# | n_updates          | 74            |
# | policy_entropy     | 1.3247507     |
# | policy_loss        | -0.0023471809 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 236           |
# | total_timesteps    | 9472          |
# | value_loss         | 1.5064459     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00062191207 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.899         |
# | fps                | 39            |
# | n_updates          | 75            |
# | policy_entropy     | 1.3292989     |
# | policy_loss        | -0.002437836  |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 240           |
# | total_timesteps    | 9600          |
# | value_loss         | 0.58134294    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010967869  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.819         |
# | fps                | 38            |
# | n_updates          | 76            |
# | policy_entropy     | 1.2982113     |
# | policy_loss        | -0.0041963668 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 243           |
# | total_timesteps    | 9728          |
# | value_loss         | 1.116429      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0006618772 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.745        |
# | fps                | 39           |
# | n_updates          | 77           |
# | policy_entropy     | 1.288812     |
# | policy_loss        | -0.003295508 |
# | serial_timesteps   | 9856         |
# | time_elapsed       | 246          |
# | total_timesteps    | 9856         |
# | value_loss         | 1.4358176    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0007073289  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.896         |
# | fps                | 38            |
# | n_updates          | 78            |
# | policy_entropy     | 1.281217      |
# | policy_loss        | -0.0020117967 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 249           |
# | total_timesteps    | 9984          |
# | value_loss         | 0.5986171     |
# --------------------------------------

# %% [markdown]
# ## Performance of PPO on the merge environment
#
# Let us evaluate the performance of the PPO on the merge environment

# %%
crashcount = 0
for i in range(10):
    done = False
    obs = env.reset()
    total_reward = []
    while not done:
        env.render()
        action, _states = ppo_highway.predict(obs)
        next_state, reward, done, info = env.step(action)
        if info['crashed']==True : crashcount +=1
        total_reward.append(reward)
        print(info)
        print(done)


rewards_average = Average(total_reward) 
  
print("The average of rewards: ",rewards_average)
print("Number of Crashes: ", crashcount)
env.close()
# Out:
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00072866988454, 'crashed': False, 'action': 0}
# False
# {'speed': 20.854565694240893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14603522286089, 'crashed': False, 'action': 4}
# False
# {'speed': 20.024955701427935, 'crashed': False, 'action': 0}
# False
# {'speed': 20.00426463576088, 'crashed': False, 'action': 0}
# False
# {'speed': 11.517674763018597, 'crashed': True, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 0}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 4}
# False
# {'speed': 24.1499473623286, 'crashed': False, 'action': 3}
# False
# {'speed': 20.70917717853974, 'crashed': False, 'action': 4}
# False
# {'speed': 20.121190036077802, 'crashed': False, 'action': 0}
# False
# {'speed': 20.020709951319613, 'crashed': False, 'action': 0}
# False
# {'speed': 20.003539087020204, 'crashed': False, 'action': 1}
# False
# {'speed': 20.00060478833307, 'crashed': False, 'action': 0}
# False
# {'speed': 20.000103351210566, 'crashed': False, 'action': 4}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 4}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 4}
# False
# {'speed': 20.0043885354593, 'crashed': False, 'action': 4}
# False
# {'speed': 24.146308775946533, 'crashed': False, 'action': 3}
# False
# {'speed': 24.854114213805673, 'crashed': False, 'action': 1}
# False
# {'speed': 24.975069835540204, 'crashed': False, 'action': 0}
# False
# {'speed': 24.99573972820653, 'crashed': False, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 20.87939323819496, 'crashed': False, 'action': 4}
# False
# {'speed': 20.150277958017302, 'crashed': False, 'action': 4}
# False
# {'speed': 20.0256807349488, 'crashed': False, 'action': 1}
# False
# {'speed': 20.0043885354593, 'crashed': False, 'action': 1}
# False
# {'speed': 20.000749949077232, 'crashed': False, 'action': 0}
# False
# {'speed': 10.032445260140856, 'crashed': True, 'action': 2}
# True
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 1}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 0}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 21.000455116798893, 'crashed': False, 'action': 4}
# False
# {'speed': 20.170966008732453, 'crashed': False, 'action': 1}
# False
# {'speed': 20.029216079413366, 'crashed': False, 'action': 4}
# False
# {'speed': 10.04036906164168, 'crashed': True, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 3}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 1}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 30.0, 'crashed': False, 'action': 2}
# False
# {'speed': 30.0, 'crashed': False, 'action': 0}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 0}
# False
# {'speed': 29.17051089193356, 'crashed': False, 'action': 3}
# False
# {'speed': 29.85825007068091, 'crashed': False, 'action': 0}
# False
# {'speed': 25.830217777950978, 'crashed': False, 'action': 4}
# False
# {'speed': 25.141874450429277, 'crashed': False, 'action': 0}
# False
# {'speed': 25.02424467437241, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00414312960259, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000708012103615, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00012099093848, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000020675927885, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000003533272817, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000000603794756, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00000010318142, 'crashed': False, 'action': 0}
# True
# {'speed': 30.0, 'crashed': False, 'action': 0}
# False
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 25.004264014349108, 'crashed': False, 'action': 1}
# False
# {'speed': 20.85516984301524, 'crashed': False, 'action': 4}
# False
# {'speed': 20.14613846477839, 'crashed': False, 'action': 4}
# False
# {'speed': 20.024973344256956, 'crashed': False, 'action': 0}
# False
# {'speed': 20.00426765071278, 'crashed': False, 'action': 1}
# False
# {'speed': 20.00072929129631, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000124627302156, 'crashed': False, 'action': 1}
# False
# {'speed': 20.00002129733965, 'crashed': False, 'action': 4}
# False
# {'speed': 20.000003639464776, 'crashed': False, 'action': 1}
# False
# {'speed': 24.14555944881101, 'crashed': False, 'action': 3}
# False
# {'speed': 24.85398616261433, 'crashed': False, 'action': 0}
# True
# {'speed': 25.8544411731307, 'crashed': False, 'action': 4}
# False
# {'speed': 25.146013943668194, 'crashed': False, 'action': 1}
# False
# {'speed': 25.024952065064255, 'crashed': False, 'action': 0}
# False
# {'speed': 29.14982284121841, 'crashed': False, 'action': 3}
# False
# {'speed': 25.709155899347046, 'crashed': False, 'action': 4}
# False
# {'speed': 25.12118639971413, 'crashed': False, 'action': 0}
# False
# {'speed': 25.020709329907845, 'crashed': False, 'action': 0}
# False
# {'speed': 25.003538980828242, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000604770186115, 'crashed': False, 'action': 2}
# False
# {'speed': 25.00010334810946, 'crashed': False, 'action': 1}
# False
# {'speed': 25.00001766097598, 'crashed': False, 'action': 0}
# False
# {'speed': 25.000003018053008, 'crashed': False, 'action': 0}
# False
# {'speed': 25.00000051574975, 'crashed': False, 'action': 1}
# False
# {'speed': 25.000000088135565, 'crashed': False, 'action': 0}
# True
# The average of rewards:  0.9096144402893805
# Number of Crashes:  3

# %% [markdown]
# The performance of the PPO algorithm is worse than the performance of the DQN algorithm and better than the performance of the agent chosing actions randomly. The average of the rewards range from 0.85-0.96 and the numbe rof crashes are 0-8
